# %% [markdown]
# ## Práctica MongoDB

# %% [markdown]
# ### Configuración incial

# %%
import json
from pymongo import MongoClient
from datetime import datetime

from collections import Counter
from pymongo.errors import WriteError

# %%
def get_db(db_name="dungeons"):
    """Conecta al servidor MongoDB que se ejecuta en localhost en el
    puerto 27017, selecciona la base de datos dungeons y la devuelve."""
    client = MongoClient("localhost", 27017)
    db = client[db_name]
    return db


def run_query(filter, project, collection_name, db_name="dungeons"):
    """Ejecuta una query genérica en la colección collection_name de la
    base de datos db_name.

    Args:
        filter: El filtro para buscar documentos (equivalente a
            la cláusula WHERE en SQL).
        project: La proyección para seleccionar qué campos incluir
            (equivalente a SELECT en SQL).
        collection_name: El nombre de la colección en la que se
            ejecutará la query.
        db_name: El nombre de la base de datos en la que se ejecutará
            la query.

    Returns:
        Un diccionario o lista de diccionarios con los resultados de la query.
    """
    db = get_db(db_name)
    result = db[collection_name].find(filter, project)
    result_list = list(result)
    result_json = json.dumps(result_list)
    result_json = json.loads(result_json)
    db.client.close()
    return result_json


def run_aggregate(pipeline, collection_name, db_name="dungeons"):
    """Ejecuta una consulta de agregación en la colección collection_name
    de la base de datos db_name.

    Args:
        pipeline: La tubería de agregación para operaciones más complejas 
            (equivalente a una serie de operaciones en SQL).
        collection_name: El nombre de la colección en la que se ejecutará
            la consulta de agregación.
        db_name: El nombre de la base de datos en la que se ejecutará.
    """
    db = get_db(db_name)
    result = db[collection_name].aggregate(pipeline)
    result_list = list(result)
    result_json = json.dumps(result_list)
    result_json = json.loads(result_json)
    db.client.close()
    return result_json


def run_insert(data, collection_name, db_name="dungeons"):
    """Inserta un documento en la colección."""
    db = get_db(db_name)
    db[collection_name].insert_one(data)
    db.client.close()


def run_append(data, collection_name, query, array_name, db_name="dungeons"):
    """Inserta un documento en un array de un documento existente.
    
    Args:
        data: El documento a insertar en el array.
        collection_name: El nombre de la colección en la que se insertará
            el documento.
        query: El filtro para encontrar el documento en el que se insertará
            el nuevo documento.
        array_name: El nombre del array en el que se insertará el documento.
        db_name: El nombre de la base de datos en la que se insertará el
            documento.
    """
    db = get_db(db_name)
    update = [
        {
            "$set": {
                array_name: {
                    "$ifNull": [{"$concatArrays": [f"${array_name}", data]}, data]
                }
            }
        }
    ]
    db[collection_name].update_many(query, update)
    db.client.close()

# %% [markdown]
# #### GET /loot: Devuelve los siguientes campos de todos los objetos del juego: idL, name.

# %%
def get_loot_data():
    # Definir el filtro y la proyección
    filter = {}
    project = {"id": 1, "name": 1, "_id": 0}

    # Ejecutar la consulta
    result = run_query(filter, project, "Loot")
    return result


get_loot_data()
# Out:
# [{'id': 2, 'name': "Alchemist's Fire (flask)"},
#  {'id': 8, 'name': 'Amulet'},
#  {'id': 20, 'name': 'Baipes'},
#  {'id': 47, 'name': 'Blunderbuss (Exandria)'},
#  {'id': 49, 'name': 'Bomb'},
#  {'id': 54, 'name': 'Breastplate'},
#  {'id': 59, 'name': "Burglar's Pack"},
#  {'id': 68, 'name': 'Carriage'},
#  {'id': 69, 'name': 'Cart'},
#  {'id': 75, 'name': 'Chain Mail'},
#  {'id': 76, 'name': 'Chain Shirt'},
#  {'id': 79, 'name': 'Chariot'},
#  {'id': 98, 'name': 'Crossbow, Hand'},
#  {'id': 100, 'name': 'Crossbow, Light'},
#  {'id': 102, 'name': 'Crystal'},
#  {'id': 107, 'name': "Diplomat's Pack"},
#  {'id': 108, 'name': 'Disguise Kit'},
#  {'id': 109, 'name': 'Dogsled'},
#  {'id': 111, 'name': 'Double-Bladed Scimitar'},
#  {'id': 120, 'name': "Dungeoneer's Pack"},
#  {'id': 128, 'name': "Entertainer's Pack"},
#  {'id': 130, 'name': "Explorer's Pack"},
#  {'id': 142, 'name': 'Glaive'},
#  {'id': 143, 'name': "Glassblower's Tools"},
#  {'id': 146, 'name': 'Greataxe'},
#  {'id': 152, 'name': 'Gunpowder, Keg'},
#  {'id': 155, 'name': 'Half Plate'},
#  {'id': 170, 'name': 'Hourglass'},
#  {'id': 215, 'name': "Monster Hunter's Pack"},
#  {'id': 221, 'name': 'Musket'},
#  {'id': 222, 'name': 'Musket (Exandria)'},
#  {'id': 232, 'name': 'Orb'},
#  {'id': 242, 'name': 'Pepperbox (Exandria)'},
#  {'id': 248, 'name': 'Pistol'},
#  {'id': 249, 'name': 'Pistol (Exandria)'},
#  {'id': 253, 'name': 'Plate'},
#  {'id': 260, 'name': 'Potion of Healing'},
#  {'id': 263, 'name': 'Pride Silk'},
#  {'id': 264, 'name': 'Pride Silk Outfit'},
#  {'id': 265, 'name': "Priest's Pack"},
#  {'id': 272, 'name': 'Rapier'},
#  {'id': 274, 'name': 'Reliquary'},
#  {'id': 282, 'name': 'Rod'},
#  {'id': 285, 'name': 'Rowboat'},
#  {'id': 288, 'name': 'Saddle, Exotic'},
#  {'id': 297, 'name': "Scholar's Pack"},
#  {'id': 298, 'name': 'Scimitar'},
#  {'id': 303, 'name': 'Shortbow'},
#  {'id': 312, 'name': 'Sled'},
#  {'id': 323, 'name': 'Spellbook'},
#  {'id': 324, 'name': 'Spiked Armor'},
#  {'id': 327, 'name': 'Splint'},
#  {'id': 329, 'name': 'Spyglass'},
#  {'id': 330, 'name': 'Staff'},
#  {'id': 336, 'name': 'Studded Leather'},
#  {'id': 361, 'name': 'Wagon'},
#  {'id': 362, 'name': 'Wand'},
#  {'id': 375, 'name': 'Wooden Staff'},
#  {'id': 377, 'name': 'Yarting'},
#  {'id': 379, 'name': 'Yew Wand'},
#  {'id': 0, 'name': 'Acid (vial)'},
#  {'id': 3, 'name': "Alchemist's Supplies"},
#  {'id': 13, 'name': 'Arrows'},
#  {'id': 17, 'name': 'Backpack'},
#  {'id': 21, 'name': 'Ball Bearings (bag of 1,000)'},
#  {'id': 24, 'name': 'Barrel'},
#  {'id': 26, 'name': 'Battleaxe'},
#  {'id': 27, 'name': 'Bedroll'},
#  {'id': 29, 'name': 'Birdpipes'},
#  {'id': 30, 'name': 'Bit and Bridle'},
#  {'id': 38, 'name': 'Block and Tackle'},
#  {'id': 42, 'name': 'Blowgun'},
#  {'id': 43, 'name': 'Blowgun Needles'},
#  {'id': 50, 'name': 'Book'},
#  {'id': 53, 'name': 'Bottle, Glass'},
#  {'id': 55, 'name': "Brewer's Supplies"},
#  {'id': 58, 'name': 'Bullets, Renaissance'},
#  {'id': 61, 'name': "Calligrapher's Supplies"},
#  {'id': 62, 'name': 'Caltrops (bag of 20)'},
#  {'id': 67, 'name': "Carpenter's Tools"},
#  {'id': 70, 'name': "Cartographer's Tools"},
#  {'id': 71, 'name': 'Case, Crossbow Bolt'},
#  {'id': 72, 'name': 'Case, Map or Scroll'},
#  {'id': 74, 'name': 'Chain (10 feet)'},
#  {'id': 80, 'name': 'Chest'},
#  {'id': 84, 'name': "Climber's Kit"},
#  {'id': 86, 'name': 'Clothes, Costume'},
#  {'id': 87, 'name': 'Clothes, Fine'},
#  {'id': 88, 'name': "Clothes, Traveler's"},
#  {'id': 89, 'name': 'Clothing, cold weather'},
#  {'id': 91, 'name': "Cobbler's Tools"},
#  {'id': 92, 'name': 'Component Pouch'},
#  {'id': 93, 'name': "Cook's Utensils"},
#  {'id': 95, 'name': 'Crampons'},
#  {'id': 97, 'name': 'Crossbow Bolts'},
#  {'id': 99, 'name': 'Crossbow, Heavy'},
#  {'id': 101, 'name': 'Crowbar'},
#  {'id': 103, 'name': 'Dagger'},
#  {'id': 113, 'name': 'Dragonchess Set'},
#  {'id': 118, 'name': 'Drum'},
#  {'id': 119, 'name': 'Dulcimer'},
#  {'id': 135, 'name': 'Fishing Tackle'},
#  {'id': 136, 'name': 'Flail'},
#  {'id': 138, 'name': 'Flute'},
#  {'id': 139, 'name': 'Forgery Kit'},
#  {'id': 144, 'name': 'Glaur'},
#  {'id': 145, 'name': 'Grappling Hook'},
#  {'id': 148, 'name': 'Greatsword'},
#  {'id': 153, 'name': 'Gunpowder, Powder Horn'},
#  {'id': 154, 'name': 'Halberd'},
#  {'id': 156, 'name': 'Hammer'},
#  {'id': 157, 'name': 'Hammer, Sledge'},
#  {'id': 158, 'name': 'Hand Drum'},
#  {'id': 161, 'name': 'Handaxe'},
#  {'id': 162, 'name': "Healer's Kit"},
#  {'id': 165, 'name': 'Herbalism Kit'},
#  {'id': 166, 'name': 'Hide'},
#  {'id': 168, 'name': 'Holy Water (flask)'},
#  {'id': 169, 'name': 'Horn'},
#  {'id': 171, 'name': 'Hunting Trap'},
#  {'id': 181, 'name': "Jeweler's Tools"},
#  {'id': 187, 'name': 'Lance'},
#  {'id': 188, 'name': 'Lantern, Bullseye'},
#  {'id': 189, 'name': 'Lantern, Hooded'},
#  {'id': 193, 'name': 'Leather'},
#  {'id': 194, 'name': "Leatherworker's Tools"},
#  {'id': 195, 'name': 'Light Hammer'},
#  {'id': 197, 'name': 'Lock'},
#  {'id': 198, 'name': 'Longbow'},
#  {'id': 199, 'name': 'Longhorn'},
#  {'id': 201, 'name': 'Longsword'},
#  {'id': 202, 'name': 'Lute'},
#  {'id': 203, 'name': 'Lyre'},
#  {'id': 204, 'name': 'Mace'},
#  {'id': 208, 'name': 'Manacles'},
#  {'id': 209, 'name': "Mason's Tools"},
#  {'id': 211, 'name': 'Maul'},
#  {'id': 214, 'name': 'Mirror, Steel'},
#  {'id': 218, 'name': 'Morningstar'},
#  {'id': 224, 'name': "Navigator's Tools"},
#  {'id': 225, 'name': 'Net'},
#  {'id': 233, 'name': 'Padded'},
#  {'id': 234, 'name': "Painter's Supplies"},
#  {'id': 236, 'name': 'Palm Pistol (Exandria)'},
#  {'id': 238, 'name': 'Pan Flute'},
#  {'id': 246, 'name': "Pick, Miner's"},
#  {'id': 247, 'name': 'Pike'},
#  {'id': 256, 'name': "Poisoner's Kit"},
#  {'id': 259, 'name': 'Pot, Iron'},
#  {'id': 261, 'name': "Potter's Tools"},
#  {'id': 269, 'name': 'Quiver'},
#  {'id': 270, 'name': 'Rain Catcher'},
#  {'id': 271, 'name': 'Ram, Portable'},
#  {'id': 280, 'name': 'Ring Mail'},
#  {'id': 281, 'name': 'Robes'},
#  {'id': 283, 'name': 'Rope, Hempen (50 feet)'},
#  {'id': 284, 'name': 'Rope, Silk (50 feet)'},
#  {'id': 289, 'name': 'Saddle, Military'},
#  {'id': 290, 'name': 'Saddle, Pack'},
#  {'id': 291, 'name': 'Saddle, Riding'},
#  {'id': 292, 'name': 'Saddlebags'},
#  {'id': 295, 'name': 'Scale Mail'},
#  {'id': 296, 'name': "Scale, Merchant's"},
#  {'id': 301, 'name': 'Shawm'},
#  {'id': 302, 'name': 'Shield'},
#  {'id': 304, 'name': 'Shortsword'},
#  {'id': 306, 'name': 'Shovel'},
#  {'id': 308, 'name': 'Sickle'},
#  {'id': 317, 'name': "Smith's Tools"},
#  {'id': 318, 'name': 'Snowshoes'},
#  {'id': 320, 'name': 'Songhorn'},
#  {'id': 322, 'name': 'Spear'},
#  {'id': 325, 'name': 'Spikes, Iron (10)'},
#  {'id': 338, 'name': 'Tantan'},
#  {'id': 340, 'name': 'Tent, Two-Person'},
#  {'id': 342, 'name': 'Thelarr'},
#  {'id': 344, 'name': "Thieves' Tools"},
#  {'id': 348, 'name': "Tinker's Tools"},
#  {'id': 349, 'name': 'Tocken'},
#  {'id': 355, 'name': 'Trident'},
#  {'id': 360, 'name': 'Viol'},
#  {'id': 363, 'name': 'War Pick'},
#  {'id': 364, 'name': 'Wargong'},
#  {'id': 365, 'name': 'Warhammer'},
#  {'id': 369, 'name': "Weaver's Tools"},
#  {'id': 371, 'name': 'Whip'},
#  {'id': 374, 'name': "Woodcarver's Tools"},
#  {'id': 380, 'name': 'Yklwa'},
#  {'id': 382, 'name': 'Zulkoon'}]

# %% [markdown]
# #### GET /loot/{loot_id}: Devuelve toda la información de un objeto del juego, incluidas las habitaciones donde aparece, de las habitaciones devuelve: idR, room_name y de la mazmorra a la que pertenece: idM, dungeon_name.

# %%
def get_loot_id(id):
    # Definir el filtro y la proyección
    filter = {"id": id}
    project = {
        "id": 1,
        "gold": 1,
        "name": 1,
        "type1": 1,
        "type2": 1,
        "weight": 1,
        "_id": 0,
        "in_rooms.room_id": 1,
        "in_rooms.room_name": 1,
        "in_rooms.dungeon_id": 1,
        "in_rooms.dungeon_name": 1,
    }

    # Ejecutar la consulta
    result = run_query(filter, project, "Loot")
    return result


get_loot_id(id=3)
# Out:
# [{'id': 3,
#   'gold': 50.0,
#   'name': "Alchemist's Supplies",
#   'type1': 'Tool',
#   'type2': 'Utility',
#   'weight': '8',
#   'in_rooms': [{'room_id': 441,
#     'room_name': 'fierce hall ',
#     'dungeon_id': 13,
#     'dungeon_name': 'Greatcliffe, Castle of the Magnificent Sumo Wrestlers'}]}]

# %% [markdown]
# #### GET /monster: Devuelve los siguientes campos de todos los monstruos del juego: idM, name, level, type.

# %%
def get_monster():
    # Definir el filtro y la proyección
    filter = {}
    project = {"id": 1, "name": 1, "level": 1, "type": 1, "_id": 0}

    # Ejecutar la consulta
    result = run_query(filter, project, "Monster")
    return result


get_monster()
# Out:
# [{'id': 3, 'name': 'rakshasa', 'type': 'fiend', 'level': 100},
#  {'id': 5, 'name': 'vampire', 'type': 'undead', 'level': 100},
#  {'id': 7, 'name': 'blink dog', 'type': 'fey', 'level': 1},
#  {'id': 8, 'name': 'acolyte', 'type': 'humanoid', 'level': 1},
#  {'id': 10, 'name': 'commoner', 'type': 'humanoid', 'level': 1},
#  {'id': 11, 'name': 'cultist', 'type': 'humanoid', 'level': 1},
#  {'id': 12, 'name': 'guard', 'type': 'humanoid', 'level': 1},
#  {'id': 15, 'name': 'flying sword', 'type': 'construct', 'level': 1},
#  {'id': 18, 'name': 'beholder', 'type': 'aberration', 'level': 100},
#  {'id': 19, 'name': 'death tyrant', 'type': 'undead', 'level': 100},
#  {'id': 21, 'name': 'crawling claw', 'type': 'undead', 'level': 1},
#  {'id': 22, 'name': 'death knight', 'type': 'undead', 'level': 100},
#  {'id': 23, 'name': 'demilich', 'type': 'undead', 'level': 100},
#  {'id': 29, 'name': 'clay golem', 'type': 'construct', 'level': 50},
#  {'id': 31, 'name': 'iron golem', 'type': 'construct', 'level': 100},
#  {'id': 32, 'name': 'stone golem', 'type': 'construct', 'level': 59},
#  {'id': 36, 'name': 'homunculus', 'type': 'construct', 'level': 1},
#  {'id': 40, 'name': 'lich', 'type': 'undead', 'level': 100},
#  {'id': 44, 'name': 'magma mephit', 'type': 'elemental', 'level': 1},
#  {'id': 45, 'name': 'mud mephit', 'type': 'elemental', 'level': 1},
#  {'id': 46, 'name': 'smoke mephit', 'type': 'elemental', 'level': 1},
#  {'id': 47, 'name': 'steam mephit', 'type': 'elemental', 'level': 1},
#  {'id': 51, 'name': 'monodrone', 'type': 'construct', 'level': 1},
#  {'id': 52, 'name': 'duodrone', 'type': 'construct', 'level': 1},
#  {'id': 53, 'name': 'tridrone', 'type': 'construct', 'level': 1},
#  {'id': 54, 'name': 'quadrone', 'type': 'construct', 'level': 2},
#  {'id': 57, 'name': 'mummy lord', 'type': 'undead', 'level': 100},
#  {'id': 60, 'name': 'guardian naga', 'type': 'monstrosity', 'level': 59},
#  {'id': 63, 'name': 'gray ooze', 'type': 'ooze', 'level': 1},
#  {'id': 66, 'name': 'shield guardian', 'type': 'construct', 'level': 29},
#  {'id': 67, 'name': 'skeleton', 'type': 'undead', 'level': 1},
#  {'id': 73, 'name': 'zombie', 'type': 'undead', 'level': 1},
#  {'id': 76, 'name': 'aarakocra', 'type': 'humanoid', 'level': 1},
#  {'id': 80, 'name': 'balor', 'type': 'fiend', 'level': 100},
#  {'id': 83, 'name': 'dretch', 'type': 'fiend', 'level': 1},
#  {'id': 84, 'name': 'glabrezu', 'type': 'fiend', 'level': 50},
#  {'id': 85, 'name': 'goristo', 'type': 'fiend', 'level': 100},
#  {'id': 87, 'name': 'manes', 'type': 'fiend', 'level': 1},
#  {'id': 88, 'name': 'marilith', 'type': 'fiend', 'level': 100},
#  {'id': 89, 'name': 'nalfeshnee', 'type': 'fiend', 'level': 100},
#  {'id': 93, 'name': 'yochlol', 'type': 'fiend', 'level': 59},
#  {'id': 96, 'name': 'bone devil', 'type': 'fiend', 'level': 50},
#  {'id': 97, 'name': 'chain devil', 'type': 'fiend', 'level': 39},
#  {'id': 98, 'name': 'erinyes', 'type': 'fiend', 'level': 84},
#  {'id': 99, 'name': 'horned devil', 'type': 'fiend', 'level': 72},
#  {'id': 100, 'name': 'ice devil', 'type': 'fiend', 'level': 100},
#  {'id': 102, 'name': 'lemure', 'type': 'fiend', 'level': 1},
#  {'id': 103, 'name': 'pit fiend', 'type': 'fiend', 'level': 100},
#  {'id': 109, 'name': 'dao', 'type': 'elemental', 'level': 72},
#  {'id': 110, 'name': 'djinni', 'type': 'elemental', 'level': 72},
#  {'id': 111, 'name': 'efreeti', 'type': 'elemental', 'level': 72},
#  {'id': 112, 'name': 'marid', 'type': 'elemental', 'level': 72},
#  {'id': 114, 'name': 'needle blight', 'type': 'plant', 'level': 1},
#  {'id': 115, 'name': 'twig blight', 'type': 'plant', 'level': 1},
#  {'id': 118, 'name': 'pixie', 'type': 'fey', 'level': 1},
#  {'id': 121, 'name': 'bulette', 'type': 'monstrosity', 'level': 18},
#  {'id': 122, 'name': 'bullywug', 'type': 'humanoid', 'level': 1},
#  {'id': 127, 'name': 'displacer beast', 'type': 'monstrosity', 'level': 7},
#  {'id': 128, 'name': 'dracolich', 'type': 'undead', 'level': 100},
#  {'id': 132, 'name': 'galeb duhr', 'type': 'elemental', 'level': 23},
#  {'id': 134, 'name': 'fire giant', 'type': 'giant', 'level': 50},
#  {'id': 137, 'name': 'stone giant', 'type': 'giant', 'level': 29},
#  {'id': 138, 'name': 'storm giant', 'type': 'giant', 'level': 100},
#  {'id': 142, 'name': 'goblin', 'type': 'goblinoid', 'level': 1},
#  {'id': 146, 'name': 'half-dragon', 'type': 'humanoid', 'level': 18},
#  {'id': 152, 'name': 'hydra', 'type': 'monstrosity', 'level': 39},
#  {'id': 153, 'name': 'jackalwere', 'type': 'humanoid', 'level': 1},
#  {'id': 154, 'name': 'kenku', 'type': 'humanoid', 'level': 1},
#  {'id': 155, 'name': 'winged kobold', 'type': 'humanoid', 'level': 1},
#  {'id': 156, 'name': 'kobold', 'type': 'humanoid', 'level': 1},
#  {'id': 157, 'name': 'kraken', 'type': 'monstrosity', 'level': 100},
#  {'id': 164, 'name': 'werewolf', 'type': 'humanoid', 'level': 7},
#  {'id': 166, 'name': 'merfolk', 'type': 'humanoid', 'level': 1},
#  {'id': 168, 'name': 'nightmare', 'type': 'fiend', 'level': 7},
#  {'id': 170, 'name': 'half-ogre', 'type': 'giant', 'level': 2},
#  {'id': 179, 'name': 'pseudodragon', 'type': 'monstrosity', 'level': 1},
#  {'id': 180, 'name': 'purple worm', 'type': 'monstrosity', 'level': 100},
#  {'id': 181, 'name': 'remorhaz', 'type': 'monstrosity', 'level': 72},
#  {'id': 183, 'name': 'roc', 'type': 'monstrosity', 'level': 72},
#  {'id': 187, 'name': 'satyr', 'type': 'fey', 'level': 1},
#  {'id': 190, 'name': 'androsphinx', 'type': 'monstrosity', 'level': 100},
#  {'id': 191, 'name': 'gynosphinx', 'type': 'monstrosity', 'level': 72},
#  {'id': 192, 'name': 'sprite', 'type': 'fey', 'level': 1},
#  {'id': 193, 'name': 'stirge', 'type': 'monstrosity', 'level': 1},
#  {'id': 194, 'name': 'tarrasque', 'type': 'monstrosity', 'level': 100},
#  {'id': 196, 'name': 'treant', 'type': 'plant', 'level': 50},
#  {'id': 203, 'name': 'abominable yeti', 'type': 'monstrosity', 'level': 50},
#  {'id': 207, 'name': 'bandit', 'type': 'humanoid', 'level': 1},
#  {'id': 209, 'name': 'scout', 'type': 'humanoid', 'level': 1},
#  {'id': 214, 'name': 'slaad tadpole', 'type': 'aberration', 'level': 1},
#  {'id': 218, 'name': 'death slaad', 'type': 'aberration', 'level': 59},
#  {'id': 221, 'name': 'arcanaloth', 'type': 'fiend', 'level': 84},
#  {'id': 223, 'name': 'nycaloth', 'type': 'fiend', 'level': 50},
#  {'id': 224, 'name': 'ultroloth', 'type': 'fiend', 'level': 100},
#  {'id': 227, 'name': 'behir', 'type': 'monstrosity', 'level': 72},
#  {'id': 229, 'name': 'cloaker', 'type': 'aberration', 'level': 39},
#  {'id': 233, 'name': 'drow', 'type': 'humanoid', 'level': 1},
#  {'id': 236, 'name': 'drow priestess', 'type': 'humanoid', 'level': 39},
#  {'id': 238, 'name': 'flumph', 'type': 'aberration', 'level': 1},
#  {'id': 239, 'name': 'fomorian', 'type': 'giant', 'level': 39},
#  {'id': 241, 'name': 'shrieker', 'type': 'plant', 'level': 1},
#  {'id': 242, 'name': 'violet fungus', 'type': 'plant', 'level': 1},
#  {'id': 246, 'name': 'grimlock', 'type': 'humanoid', 'level': 1},
#  {'id': 248, 'name': 'kuo-toa', 'type': 'humanoid', 'level': 1},
#  {'id': 251, 'name': 'myconid sprout', 'type': 'plant', 'level': 1},
#  {'id': 256, 'name': 'otyugh', 'type': 'aberration', 'level': 18},
#  {'id': 257, 'name': 'piercer', 'type': 'monstrosity', 'level': 1},
#  {'id': 261, 'name': 'troglodyte', 'type': 'humanoid', 'level': 1},
#  {'id': 263, 'name': 'aboleth', 'type': 'aberration', 'level': 59},
#  {'id': 0, 'name': 'doppelganger', 'type': 'monstrosity', 'level': 7},
#  {'id': 1, 'name': 'gargoyle', 'type': 'elemental', 'level': 4},
#  {'id': 2, 'name': 'wererat', 'type': 'humanoid', 'level': 4},
#  {'id': 4, 'name': 'revenant', 'type': 'undead', 'level': 18},
#  {'id': 6, 'name': 'vampire spawn', 'type': 'undead', 'level': 18},
#  {'id': 9, 'name': 'assassin', 'type': 'humanoid', 'level': 39},
#  {'id': 13, 'name': 'thug', 'type': 'humanoid', 'level': 1},
#  {'id': 14, 'name': 'animated armor', 'type': 'construct', 'level': 2},
#  {'id': 16, 'name': 'rug of smothering', 'type': 'construct', 'level': 4},
#  {'id': 17, 'name': 'banshee', 'type': 'undead', 'level': 11},
#  {'id': 20, 'name': 'spectator', 'type': 'aberration', 'level': 7},
#  {'id': 24, 'name': 'flameskull', 'type': 'undead', 'level': 11},
#  {'id': 25, 'name': 'ghost', 'type': 'undead', 'level': 11},
#  {'id': 26, 'name': 'ghast', 'type': 'undead', 'level': 4},
#  {'id': 27, 'name': 'ghoul', 'type': 'undead', 'level': 2},
#  {'id': 28, 'name': 'gibbering mouther', 'type': 'aberration', 'level': 4},
#  {'id': 30, 'name': 'flesh golem', 'type': 'construct', 'level': 18},
#  {'id': 33, 'name': 'gorgon', 'type': 'monstrosity', 'level': 18},
#  {'id': 34, 'name': 'grell', 'type': 'aberration', 'level': 7},
#  {'id': 35, 'name': 'helmed horror', 'type': 'construct', 'level': 11},
#  {'id': 37, 'name': 'intellect devourer', 'type': 'aberration', 'level': 4},
#  {'id': 38, 'name': 'invisible stalker', 'type': 'elemental', 'level': 23},
#  {'id': 39, 'name': 'lamia', 'type': 'monstrosity', 'level': 11},
#  {'id': 41, 'name': 'medusa', 'type': 'monstrosity', 'level': 23},
#  {'id': 42, 'name': 'dust mephit', 'type': 'elemental', 'level': 1},
#  {'id': 43, 'name': 'ice mephit', 'type': 'elemental', 'level': 1},
#  {'id': 48, 'name': 'mimic', 'type': 'monstrosity', 'level': 4},
#  {'id': 49, 'name': 'mind flayer', 'type': 'aberration', 'level': 29},
#  {'id': 50, 'name': 'minotaur', 'type': 'monstrosity', 'level': 7},
#  {'id': 55, 'name': 'pentadrone', 'type': 'construct', 'level': 4},
#  {'id': 56, 'name': 'mummy', 'type': 'undead', 'level': 7},
#  {'id': 58, 'name': 'bone naga', 'type': 'undead', 'level': 11},
#  {'id': 59, 'name': 'spirit naga', 'type': 'monstrosity', 'level': 39},
#  {'id': 61, 'name': 'black pudding', 'type': 'ooze', 'level': 11},
#  {'id': 62, 'name': 'gelatinous cube', 'type': 'ooze', 'level': 4},
#  {'id': 64, 'name': 'ochre jelly', 'type': 'ooze', 'level': 4},
#  {'id': 65, 'name': 'shadow', 'type': 'undead', 'level': 1},
#  {'id': 68, 'name': 'minotaur skeleton', 'type': 'undead', 'level': 4},
#  {'id': 69, 'name': 'warhorse skeleton', 'type': 'undead', 'level': 1},
#  {'id': 70, 'name': 'specter', 'type': 'undead', 'level': 2},
#  {'id': 71, 'name': 'wight', 'type': 'undead', 'level': 7},
#  {'id': 72, 'name': 'wraith', 'type': 'undead', 'level': 18},
#  {'id': 74, 'name': 'beholder zombie', 'type': 'undead', 'level': 18},
#  {'id': 75, 'name': 'ogre zombie', 'type': 'undead', 'level': 4},
#  {'id': 77, 'name': 'azer', 'type': 'elemental', 'level': 4},
#  {'id': 78, 'name': 'cambion', 'type': 'fiend', 'level': 18},
#  {'id': 79, 'name': 'couatl', 'type': 'celestial', 'level': 11},
#  {'id': 81, 'name': 'barlgura', 'type': 'fiend', 'level': 18},
#  {'id': 82, 'name': 'chasme', 'type': 'fiend', 'level': 23},
#  {'id': 86, 'name': 'hezrou', 'type': 'fiend', 'level': 39},
#  {'id': 90, 'name': 'quasit', 'type': 'fiend', 'level': 2},
#  {'id': 91, 'name': 'shadow demon', 'type': 'fiend', 'level': 11},
#  {'id': 92, 'name': 'vrock', 'type': 'fiend', 'level': 23},
#  {'id': 94, 'name': 'barbed devil', 'type': 'fiend', 'level': 18},
#  {'id': 95, 'name': 'bearded devil', 'type': 'fiend', 'level': 7},
#  {'id': 101, 'name': 'imp', 'type': 'fiend', 'level': 2},
#  {'id': 104, 'name': 'spined devil', 'type': 'fiend', 'level': 4},
#  {'id': 105, 'name': 'air elemental', 'type': 'elemental', 'level': 18},
#  {'id': 106, 'name': 'earth elemental', 'type': 'elemental', 'level': 18},
#  {'id': 107, 'name': 'fire elemental', 'type': 'elemental', 'level': 18},
#  {'id': 108, 'name': 'water elemental', 'type': 'elemental', 'level': 18},
#  {'id': 113, 'name': 'hell hound', 'type': 'fiend', 'level': 7},
#  {'id': 116, 'name': 'vine blight', 'type': 'plant', 'level': 1},
#  {'id': 117, 'name': 'driad', 'type': 'fey', 'level': 2},
#  {'id': 119, 'name': 'bugbear', 'type': 'goblinoid', 'level': 2},
#  {'id': 120, 'name': 'bugbear chief', 'type': 'goblinoid', 'level': 7},
#  {'id': 123, 'name': 'centaur', 'type': 'monstrosity', 'level': 4},
#  {'id': 124, 'name': 'chimera', 'type': 'monstrosity', 'level': 23},
#  {'id': 125, 'name': 'cockatrice', 'type': 'monstrosity', 'level': 1},
#  {'id': 126, 'name': 'cyclops', 'type': 'giant', 'level': 23},
#  {'id': 129, 'name': 'ettin', 'type': 'giant', 'level': 11},
#  {'id': 130, 'name': 'faerie dragon r/o/y', 'type': 'fey', 'level': 2},
#  {'id': 131, 'name': 'faerie dragon g/b/i/v', 'type': 'fey', 'level': 4},
#  {'id': 133, 'name': 'cloud giant', 'type': 'giant', 'level': 50},
#  {'id': 135, 'name': 'frost giant', 'type': 'giant', 'level': 39},
#  {'id': 136, 'name': 'hill giant', 'type': 'giant', 'level': 18},
#  {'id': 139, 'name': 'gnoll', 'type': 'humanoid', 'level': 1},
#  {'id': 140, 'name': 'gnoll pack lord', 'type': 'humanoid', 'level': 4},
#  {'id': 141,
#   'name': 'gnoll fang of yeenoghu',
#   'type': 'humanoid',
#   'level': 11},
#  {'id': 143, 'name': 'goblin boss', 'type': 'goblinoid', 'level': 2},
#  {'id': 144, 'name': 'griffon', 'type': 'monstrosity', 'level': 4},
#  {'id': 145, 'name': 'night hag', 'type': 'fey', 'level': 18},
#  {'id': 147, 'name': 'harpy', 'type': 'monstrosity', 'level': 2},
#  {'id': 148, 'name': 'hippogriff', 'type': 'monstrosity', 'level': 2},
#  {'id': 149, 'name': 'hobgoblin', 'type': 'goblinoid', 'level': 1},
#  {'id': 150, 'name': 'hobgoblin captain', 'type': 'goblinoid', 'level': 7},
#  {'id': 151, 'name': 'hobgoblin warlord', 'type': 'goblinoid', 'level': 23},
#  {'id': 158, 'name': 'lizardfolk', 'type': 'humanoid', 'level': 1},
#  {'id': 159, 'name': 'lizardfolk shaman', 'type': 'humanoid', 'level': 4},
#  {'id': 160, 'name': 'lizardfolk royal', 'type': 'humanoid', 'level': 11},
#  {'id': 161, 'name': 'werebear', 'type': 'humanoid', 'level': 18},
#  {'id': 162, 'name': 'wereboar', 'type': 'humanoid', 'level': 11},
#  {'id': 163, 'name': 'weretiger', 'type': 'humanoid', 'level': 11},
#  {'id': 165, 'name': 'manticore', 'type': 'monstrosity', 'level': 7},
#  {'id': 167, 'name': 'merrow', 'type': 'monstrosity', 'level': 4},
#  {'id': 169, 'name': 'ogre', 'type': 'giant', 'level': 4},
#  {'id': 171, 'name': 'oni', 'type': 'giant', 'level': 29},
#  {'id': 172, 'name': 'orc', 'type': 'humanoid', 'level': 1},
#  {'id': 173, 'name': 'orc war chief', 'type': 'humanoid', 'level': 11},
#  {'id': 174, 'name': 'orc eye of gruumsh', 'type': 'humanoid', 'level': 4},
#  {'id': 175, 'name': 'orog', 'type': 'humanoid', 'level': 4},
#  {'id': 176, 'name': 'owlbear', 'type': 'monstrosity', 'level': 7},
#  {'id': 177, 'name': 'pegasus', 'type': 'celestial', 'level': 4},
#  {'id': 178, 'name': 'peryton', 'type': 'monstrosity', 'level': 4},
#  {'id': 182, 'name': 'young remorhaz', 'type': 'monstrosity', 'level': 18},
#  {'id': 184, 'name': 'sahuagin', 'type': 'humanoid', 'level': 1},
#  {'id': 185, 'name': 'sahuagin priestess', 'type': 'humanoid', 'level': 4},
#  {'id': 186, 'name': 'sahuagin baron', 'type': 'humanoid', 'level': 18},
#  {'id': 188, 'name': 'scarecrow', 'type': 'undead', 'level': 2},
#  {'id': 189, 'name': 'shambling mound', 'type': 'plant', 'level': 18},
#  {'id': 195, 'name': 'thri-kreen', 'type': 'humanoid', 'level': 2},
#  {'id': 197, 'name': 'troll', 'type': 'giant', 'level': 18},
#  {'id': 198, 'name': 'unicorn', 'type': 'celestial', 'level': 18},
#  {'id': 199, 'name': 'water weird', 'type': 'elemental', 'level': 7},
#  {'id': 200, 'name': 'will-o-wisp', 'type': 'undead', 'level': 4},
#  {'id': 201, 'name': 'wyvern', 'type': 'monstrosity', 'level': 23},
#  {'id': 202, 'name': 'yeti', 'type': 'monstrosity', 'level': 7},
#  {'id': 204,
#   'name': 'yuan-ti abomination',
#   'type': 'monstrosity',
#   'level': 29},
#  {'id': 205, 'name': 'yuan-ti malison', 'type': 'monstrosity', 'level': 7},
#  {'id': 206, 'name': 'yuan-ti pureblood', 'type': 'monstrosity', 'level': 2},
#  {'id': 208, 'name': 'bandit captain', 'type': 'humanoid', 'level': 4},
#  {'id': 210, 'name': 'magmin', 'type': 'elemental', 'level': 1},
#  {'id': 211, 'name': 'fire snake', 'type': 'elemental', 'level': 2},
#  {'id': 212, 'name': 'salamander', 'type': 'elemental', 'level': 18},
#  {'id': 213, 'name': 'red slaad', 'type': 'aberration', 'level': 18},
#  {'id': 215, 'name': 'blue slaad', 'type': 'aberration', 'level': 29},
#  {'id': 216, 'name': 'green slaad', 'type': 'aberration', 'level': 39},
#  {'id': 217, 'name': 'grey slaad', 'type': 'aberration', 'level': 50},
#  {'id': 219, 'name': 'succubus', 'type': 'fiend', 'level': 11},
#  {'id': 220, 'name': 'xorn', 'type': 'elemental', 'level': 18},
#  {'id': 222, 'name': 'mezzoloth', 'type': 'fiend', 'level': 18},
#  {'id': 225, 'name': 'ankheg', 'type': 'monstrosity', 'level': 4},
#  {'id': 226, 'name': 'basilisk', 'type': 'monstrosity', 'level': 7},
#  {'id': 228, 'name': 'carrion crawler', 'type': 'monstrosity', 'level': 4},
#  {'id': 230, 'name': 'darkmantle', 'type': 'monstrosity', 'level': 1},
#  {'id': 231, 'name': 'drider', 'type': 'monstrosity', 'level': 23},
#  {'id': 232, 'name': 'duergar', 'type': 'humanoid', 'level': 2},
#  {'id': 234, 'name': 'drow elite warrior', 'type': 'humanoid', 'level': 18},
#  {'id': 235, 'name': 'drow mage', 'type': 'humanoid', 'level': 29},
#  {'id': 237, 'name': 'ettercap', 'type': 'monstrosity', 'level': 4},
#  {'id': 240, 'name': 'gas spore', 'type': 'plant', 'level': 1},
#  {'id': 243, 'name': 'deep gnome', 'type': 'humanoid', 'level': 1},
#  {'id': 244, 'name': 'grick', 'type': 'monstrosity', 'level': 4},
#  {'id': 245, 'name': 'grick alpha', 'type': 'monstrosity', 'level': 29},
#  {'id': 247, 'name': 'hook horror', 'type': 'monstrosity', 'level': 7},
#  {'id': 249, 'name': 'kuo-toa archpriest', 'type': 'humanoid', 'level': 23},
#  {'id': 250, 'name': 'kuo-toa whip', 'type': 'humanoid', 'level': 2},
#  {'id': 252, 'name': 'spore servant', 'type': 'plant', 'level': 2},
#  {'id': 253, 'name': 'myconid adult', 'type': 'plant', 'level': 1},
#  {'id': 254, 'name': 'myconid sovereign', 'type': 'plant', 'level': 4},
#  {'id': 255, 'name': 'nothic', 'type': 'aberration', 'level': 4},
#  {'id': 258, 'name': 'quaggoth', 'type': 'humanoid', 'level': 4},
#  {'id': 259, 'name': 'roper', 'type': 'monstrosity', 'level': 18},
#  {'id': 260, 'name': 'rust monster', 'type': 'monstrosity', 'level': 1},
#  {'id': 262, 'name': 'umber hulk', 'type': 'monstrosity', 'level': 18},
#  {'id': 264, 'name': 'chuul', 'type': 'aberration', 'level': 11},
#  {'id': 265, 'name': 'sea hag', 'type': 'fey', 'level': 4}]

# %% [markdown]
# #### GET /monster/{monster_id}: Devuelve toda la información sobre un monstruo del juego, incluidas las habitaciones donde aparecen, de las habitaciones devuelve: idR, room_name y de la mazmorra a la que pertenece: idM, dungeon_name.

# %%
def get_monster_id(id):
    # Definir el filtro y la proyección
    filter = {"id": id}
    project = {
        "id": 1,
        "exp": 1,
        "name": 1,
        "type": 1,
        "level": 1,
        "place": 1,
        "man_page": 1,
        "_id": 0,
        "in_rooms.room_id": 1,
        "in_rooms.room_name": 1,
        "in_rooms.dungeon_id": 1,
        "in_rooms.dungeon_name": 1,
    }

    # Ejecutar la consulta
    result = run_query(filter, project, "Monster")
    return result


get_monster_id(id=3)
# Out:
# [{'id': 3,
#   'exp': 10000,
#   'name': 'rakshasa',
#   'type': 'fiend',
#   'level': 100,
#   'place': 'city',
#   'man_page': 257}]

# %% [markdown]
# #### GET /dungeon: Devuelve los siguientes campos de todas las mazmorras del juego: idD, name.

# %%
def get_dungeon():
    """Agrupa las habitaciones por dungeon_name y dungeon_id para obtener 
    todas las mazmorras."""
    # Definir el filtro y la proyección
    pipeline = [
        {
            "$group": {
                "_id": {"dungeon_name": "$dungeon_name", "dungeon_id": "$dungeon_id"}
            }
        },
        {"$replaceRoot": {"newRoot": "$_id"}},
    ]

    # Ejecutar la consulta
    result = run_aggregate(pipeline, "Rooms")
    return result


get_dungeon()
# Out:
# [{'dungeon_name': 'Schyppegarth, Laboratory of the Sticky Robots',
#   'dungeon_id': 14},
#  {'dungeon_name': 'Withystream, Castle of the Screeching Otaku',
#   'dungeon_id': 4},
#  {'dungeon_name': 'Garthwort, Mines of the Elderly Emperors',
#   'dungeon_id': 18},
#  {'dungeon_name': 'Shadysparth, Hobble of the Wandering Stoners',
#   'dungeon_id': 2},
#  {'dungeon_name': 'Burghap, Prison of the Jealous Hippies', 'dungeon_id': 0},
#  {'dungeon_name': 'Marshgreat, Catacombs of the Wandering Degenerates',
#   'dungeon_id': 17},
#  {'dungeon_name': 'Dalhylles, Culverts of the Grumpy Bandits',
#   'dungeon_id': 19},
#  {'dungeon_name': 'Watergarth, Stockade of the Feminist Presidents',
#   'dungeon_id': 7},
#  {'dungeon_name': 'Corrieclock, Pit of the Sexy Unknowns', 'dungeon_id': 15},
#  {'dungeon_name': 'Greatcliffe, Castle of the Magnificent Sumo Wrestlers',
#   'dungeon_id': 13},
#  {'dungeon_name': 'Burgstream, Culverts of the Bashful Sumo Wrestlers',
#   'dungeon_id': 1},
#  {'dungeon_name': 'Wanton, Culverts of the Jealous Thieves', 'dungeon_id': 3},
#  {'dungeon_name': 'Fenwater, Hobble of the Fierce Furries', 'dungeon_id': 5},
#  {'dungeon_name': 'Spleensparth, Mines of the Panicky Otaku', 'dungeon_id': 8},
#  {'dungeon_name': 'Alaunstream, Pit of the Jolly Scientists', 'dungeon_id': 9},
#  {'dungeon_name': 'Corriedal, Sewers of the Terrible Emperors',
#   'dungeon_id': 10},
#  {'dungeon_name': 'Strathglass, Mausoleum of the Repulsive Ninjas',
#   'dungeon_id': 12},
#  {'dungeon_name': 'Arvaleclock, Dungeon of the Snobbish Scientists',
#   'dungeon_id': 6},
#  {'dungeon_name': 'Dalshady, Cave of the Old-Fashioned Otaku',
#   'dungeon_id': 16},
#  {'dungeon_name': 'Bentalaun, Vault of the Old-Fashioned Pirates',
#   'dungeon_id': 11}]

# %% [markdown]
# #### GET /dungeon/{dungeon_id}: Devuelve información sobre una mazmorra del juego. Debe devolver: idM, name y lore. Además, este endpoint se utiliza para alimentar un grafo interactivo por lo que requiere la siguiente información:
# 1) El nombre e id de cada habitación de la mazmorra.
# 2) Las conexiones entre habitaciones de la mazmorra.
# 3) El id y el nombre de los monstruos que aparecen en cada habitación.
# 4) El id y el nombre de los tesoros que aparecen en cada habitación.
# 5) El número de comentarios de cada categoría que hay en cada habitación.

# %%
def get_dungeon_id(id):

    # Definir el filtro y la proyección
    pipeline_1 = [
        {"$match": {"dungeon_id": id}},
        {"$unwind": "$hints"},
        {"$match": {"hints.category": "lore"}},
        {
            "$group": {
                "_id": {"id": "$dungeon_id", "name": "$dungeon_name"},
                "lore": {"$push": {"text": "$hints.hintText",
                                   "creation_date": "$hints.creation_date",
                                   "publish_by": "$hints.publish_by.email"}},
            }
        },
    ]

    # Ejecutar la consulta
    result_1 = run_aggregate(pipeline_1, "Rooms")

    # Realizmos una segunda consulta para
    pipeline_2 = [
        {"$match": {"dungeon_id": id}},
        {
            "$group": {
                "_id": "$dungeon_name",
                "data": {
                    "$push": {
                        "room_id": "$room_id",
                        "name": "$room_name",
                        "Monster": "$monsters",
                        "Loot": "$loot",
                        "n_size": {"$size": {"$ifNull": ["$hints", []]}},
                        "room_connections": "$rooms_connected",
                    }
                },
            }
        },
    ]

    # Ejecutar la consulta
    result_2 = run_aggregate(pipeline_2, "Rooms")

    result_1[0]["data"] = result_2[0]["data"]
    return result_1


get_dungeon_id(id=0)
# Out:
# [{'_id': {'id': 0, 'name': 'Burghap, Prison of the Jealous Hippies'},
#   'lore': [{'text': 'Граница пропаганда банк домашний роскошный. Неожиданно обида уточнить прощение. Вообще намерение палец рассуждение задержать дьявол. Советовать еврейский увеличиваться ботинок опасность угодный.\\nУточнить пища народ бетонный избегать эпоха возникновение плясать. Новый увеличиваться полюбить природа второй правление. Расстройство ягода рай выгнать поколение мягкий решение.',
#     'creation_date': '2022-03-21 06:01:50.000000',
#     'publish_by': 'rodion_2002@example.net'},
#    {'text': 'Die Sonne Licht schnell zeigen Geburtstag kennen. Las darin hängen wichtig Vogel heiß vom nimmt. Fröhlich Abend Teller rechnen. Grün einfach fast.\\nSelbst haben hören wirklich. Verstecken Zahl sitzen Hund schwimmen baden lange. Weil gleich nichts Stunde. Bin Freund gleich zum essen.\\nWeiß dumm doch einfach Lehrer Mann kommen. Müssen Glück Leute heute los gut wird.\\nGar steigen Wetter gehören Frage um Wagen tragen. Sieht Bett rufen.\\nBin Hase Seite dort Weihnachten einige. Verlieren glauben bald Stüc',
#     'creation_date': '2018-12-22 01:16:11.000000',
#     'publish_by': 'pmo@example.org'},
#    {'text': 'Necessitatibus voluptatem fugit facilis ipsam inventore. Quos dolores architecto animi vitae quidem consectetur.\\nLabore a aliquid inventore laudantium enim quis. Sequi quo sed consequatur minima deserunt. Mollitia exercitationem quia iste quam atque minus esse.\\nCupiditate itaque accusantium quam iure unde ipsa. Provident culpa vel in vitae. Odit nostrum eius dolorum dolorem.\\nRecusandae similique quod consequuntur. Delectus repudiandae dolorum. Officia saepe nam expedita.\\nSaepe facilis sit incidu',
#     'creation_date': '2020-01-20 11:59:14.000000',
#     'publish_by': 'sanghyeonhan@example.net'},
#    {'text': '日期認為的話你們學習對於注冊.\\n具有銷售管理搜索雖然包括論壇.應用汽車發現隻有.\\n學生信息價格.商品全國由於以上.為了國內然后數據實現積分計劃組織.\\n公司一下使用一次實現.一些結果用戶而且這些留言覺得工作.主要女人商品國際資源所以大學.\\n世界上海無法解決如何評論.\\n需要不斷隻有如果發布.以下知道業務擁有建設一種的話工具.進入生產表示汽車這是.\\n一切其他顯示合作如果必須使用.看到威望經濟台灣有限一次一點次數.\\n游戲發展方面各種特別以后都是顯示.點擊用戶得到不同.\\n更新那些部分技術.一直應用就是音樂簡介不能一切控制.\\n一般不過如果本站方法過程還有.她的但是標題制作科技資源大小.\\n學生單位有關完成.我的發布設計的是.\\n在線因此影響今天建設.如果進行兩個都是記者.單位看到游戲我們單位雖然無法.\\n一下銷售威望最新設計需要時間.論壇等級環境有限台北一點提供.文件一次准備首頁人員簡介.\\n他的部門活動不過價格.名稱首頁方式地方得到如此.軟體質量那個人員.\\n空間安全行業標准.這種標准不過不是實現希望資源.大家合作不是或者出現自己介紹.\\n希望那麼他的.制作服務一點不是.\\n包括類型之間你們品牌.作者空間開發',
#     'creation_date': '2016-04-10 23:39:59.000000',
#     'publish_by': 'yinguiying@example.org'},
#    {'text': 'May evening suggest risk structure authority. Whose scene drive hope can price fear character. Market from artist.\\nDinner democratic college identify. Speak car argue son carry dinner plan. Indeed some great morning line guess short. Ground eat strong.\\nWith a art wind seven avoid color.\\nTreat green avoid federal war. Mouth piece sell lay oil. Red full as especially drive professor safe.\\nThird kid home personal term safe. Back keep road case.\\nPlayer police security house food sound maybe. Produce',
#     'creation_date': '2015-11-03 11:34:45.000000',
#     'publish_by': 'bonillajeffrey@example.com'},
#    {'text': 'Realize themselves me forget. Sound claim hard usually model western safe.\\nAlready church until each deep. A firm follow its station position.\\nThrow common firm know compare draw. Seat his land allow probably court in. Away describe himself space shake. Recognize general foreign like minute just.\\nThus two ago daughter. Practice option accept personal travel. High be election buy expert throughout city.\\nBoth few sit experience south while fight. Her young wide no. Order over door trial.\\nSource fi',
#     'creation_date': '2014-12-07 12:55:22.000000',
#     'publish_by': 'davidsonmadison@example.org'},
#    {'text': 'Top yard else along high. Model military war national thousand. Police if data seek easy population nothing.\\nChoose could scene direction thought. Actually various though control nearly newspaper.\\nAbove with large. Generation recent hundred value we treat special. Kitchen but early.\\nThemselves daughter nor read suffer. Establish seven condition try strategy. Necessary put only night class before act.\\nIndicate forward physical parent. Where coach great fill. Lawyer day apply may though affect gen',
#     'creation_date': '2015-04-09 06:55:12.000000',
#     'publish_by': 'qboone@example.net'},
#    {'text': 'Fermer face système. Étendue pouvoir traîner pauvre banc. Trois dame cruel siècle.\\nArriver écraser grave aile revenir. Vue port environ toujours grain fixe pierre achever. Époque écrire abandonner dangereux portier. Lentement travers lentement pourtant extraordinaire.\\nAccuser visite énorme souffler. Source occuper tant profond.\\nAccuser tache grave séparer grâce reculer enfoncer. Vieux écarter accord arrêter discussion soin. Victime jeune abri autrement regard faveur.\\nVite léger repousser atteind',
#     'creation_date': '2017-12-15 02:05:06.000000',
#     'publish_by': 'agnes77@example.com'},
#    {'text': '需要更多這是工程.其實新聞希望繼續應用.研究社區出來威望記者.\\n中文地方對於.產品內容能夠.\\n那些專業主題所以.日本大學不是孩子.\\n正在說明語言今年.可是其他以后就是服務處理政府精華.一個今年發布全國女人我們.\\n起來評論如果建設決定主題時間.不要開始評論目前.來自以后政府直接之間上海歡迎.\\n出來電影任何.能夠回復類型技術等級公司簡介以下.\\n無法那麼如果學校.原因狀態標題關系是否最后.成為希望社區密碼.\\n然后簡介相關的人標准專業發展.部分音樂國際品牌.原因謝謝名稱成為目前准備一種.\\n學生無法他的支持成功不是他的.由於已經增加希望技術社區解決生產.\\n我的教育幫助地方不能學習主題.但是資料一起部分相關當前.\\n積分詳細廣告上海網絡學校一下.控制教育能力能力方面不會制作方式.加入有關所以台北有關有關.\\n到了地址日本全部.質量使用詳細地址工作政府.\\n不同全國當前以及狀態語言推薦.所以活動地方.積分一點就是出現女人部門.\\n美國上海目前地址.作為必須現在管理起來控制.作為已經如果美國.\\n首頁規定簡介城市部門如此.選擇電腦工具科技質量以后.游戲地址積分行業.\\n知道她的生產她的.精華免費研究能夠城市增加.',
# ...
#      {'id': 197,
#       'gold': 10.0,
#       'name': 'Lock',
#       'type1': 'Adventuring Gear',
#       'type2': 'Utility, Warding',
#       'weight': '1'},
#      {'id': 197,
#       'gold': 10.0,
#       'name': 'Lock',
#       'type1': 'Adventuring Gear',
#       'type2': 'Utility, Warding',
#       'weight': '1'},
#      {'id': 197,
#       'gold': 10.0,
#       'name': 'Lock',
#       'type1': 'Adventuring Gear',
#       'type2': 'Utility, Warding',
#       'weight': '1'},
#      {'id': 197,
#       'gold': 10.0,
#       'name': 'Lock',
#       'type1': 'Adventuring Gear',
#       'type2': 'Utility, Warding',
#       'weight': '1'},
#      {'id': 197,
#       'gold': 10.0,
#       'name': 'Lock',
#       'type1': 'Adventuring Gear',
#       'type2': 'Utility, Warding',
#       'weight': '1'},
#      {'id': 197,
#       'gold': 10.0,
#       'name': 'Lock',
#       'type1': 'Adventuring Gear',
#       'type2': 'Utility, Warding',
#       'weight': '1'},
#      {'id': 197,
#       'gold': 10.0,
#       'name': 'Lock',
#       'type1': 'Adventuring Gear',
#       'type2': 'Utility, Warding',
#       'weight': '1'},
#      {'id': 197,
#       'gold': 10.0,
#       'name': 'Lock',
#       'type1': 'Adventuring Gear',
#       'type2': 'Utility, Warding',
#       'weight': '1'},
#      {'id': 197,
#       'gold': 10.0,
#       'name': 'Lock',
#       'type1': 'Adventuring Gear',
#       'type2': 'Utility, Warding',
#       'weight': '1'},
#      {'id': 197,
#       'gold': 10.0,
#       'name': 'Lock',
#       'type1': 'Adventuring Gear',
#       'type2': 'Utility, Warding',
#       'weight': '1'},
#      {'id': 197,
#       'gold': 10.0,
#       'name': 'Lock',
#       'type1': 'Adventuring Gear',
#       'type2': 'Utility, Warding',
#       'weight': '1'},
#      {'id': 197,
#       'gold': 10.0,
#       'name': 'Lock',
#       'type1': 'Adventuring Gear',
#       'type2': 'Utility, Warding',
#       'weight': '1'},
#      {'id': 197,
#       'gold': 10.0,
#       'name': 'Lock',
#       'type1': 'Adventuring Gear',
#       'type2': 'Utility, Warding',
#       'weight': '1'},
#      {'id': 197,
#       'gold': 10.0,
#       'name': 'Lock',
#       'type1': 'Adventuring Gear',
#       'type2': 'Utility, Warding',
#       'weight': '1'},
#      {'id': 197,
#       'gold': 10.0,
#       'name': 'Lock',
#       'type1': 'Adventuring Gear',
#       'type2': 'Utility, Warding',
#       'weight': '1'},
#      {'id': 197,
#       'gold': 10.0,
#       'name': 'Lock',
#       'type1': 'Adventuring Gear',
#       'type2': 'Utility, Warding',
#       'weight': '1'},
#      {'id': 197,
#       'gold': 10.0,
#       'name': 'Lock',
#       'type1': 'Adventuring Gear',
#       'type2': 'Utility, Warding',
#       'weight': '1'},
#      {'id': 197,
#       'gold': 10.0,
#       'name': 'Lock',
#       'type1': 'Adventuring Gear',
#       'type2': 'Utility, Warding',
#       'weight': '1'},
#      {'id': 197,
#       'gold': 10.0,
#       'name': 'Lock',
#       'type1': 'Adventuring Gear',
#       'type2': 'Utility, Warding',
#       'weight': '1'},
#      {'id': 197,
#       'gold': 10.0,
#       'name': 'Lock',
#       'type1': 'Adventuring Gear',
#       'type2': 'Utility, Warding',
#       'weight': '1'},
#      {'id': 197,
#       'gold': 10.0,
#       'name': 'Lock',
#       'type1': 'Adventuring Gear',
#       'type2': 'Utility, Warding',
#       'weight': '1'},
#      {'id': 197,
#       'gold': 10.0,
#       'name': 'Lock',
#       'type1': 'Adventuring Gear',
#       'type2': 'Utility, Warding',
#       'weight': '1'},
#      {'id': 197,
#       'gold': 10.0,
#       'name': 'Lock',
#       'type1': 'Adventuring Gear',
#       'type2': 'Utility, Warding',
#       'weight': '1'},
#      {'id': 197,
#       'gold': 10.0,
#       'name': 'Lock',
#       'type1': 'Adventuring Gear',
#       'type2': 'Utility, Warding',
#       'weight': '1'},
#      {'id': 197,
#       'gold': 10.0,
#       'name': 'Lock',
#       'type1': 'Adventuring Gear',
#       'type2': 'Utility, Warding',
#       'weight': '1'},
#      {'id': 197,
#       'gold': 10.0,
#       'name': 'Lock',
#       'type1': 'Adventuring Gear',
#       'type2': 'Utility, Warding',
#       'weight': '1'},
#      {'id': 197,
#       'gold': 10.0,
#       'name': 'Lock',
#       'type1': 'Adventuring Gear',
#       'type2': 'Utility, Warding',
#       'weight': '1'},
#      {'id': 197,
#       'gold': 10.0,
#       'name': 'Lock',
#       'type1': 'Adventuring Gear',
#       'type2': 'Utility, Warding',
#       'weight': '1'},
#      {'id': 197,
#       'gold': 10.0,
#       'name': 'Lock',
#       'type1': 'Adventuring Gear',
#       'type2': 'Utility, Warding',
#       'weight': '1'},
#      {'id': 197,
#       'gold': 10.0,
#       'name': 'Lock',
#       'type1': 'Adventuring Gear',
#       'type2': 'Utility, Warding',
#       'weight': '1'},
#      {'id': 197,
#       'gold': 10.0,
#       'name': 'Lock',
#       'type1': 'Adventuring Gear',
#       'type2': 'Utility, Warding',
#       'weight': '1'},
#      {'id': 197,
#       'gold': 10.0,
#       'name': 'Lock',
#       'type1': 'Adventuring Gear',
#       'type2': 'Utility, Warding',
#       'weight': '1'},
#      {'id': 197,
#       'gold': 10.0,
#       'name': 'Lock',
#       'type1': 'Adventuring Gear',
#       'type2': 'Utility, Warding',
#       'weight': '1'},
#      {'id': 197,
#       'gold': 10.0,
#       'name': 'Lock',
#       'type1': 'Adventuring Gear',
#       'type2': 'Utility, Warding',
#       'weight': '1'},
#      {'id': 197,
#       'gold': 10.0,
#       'name': 'Lock',
#       'type1': 'Adventuring Gear',
#       'type2': 'Utility, Warding',
#       'weight': '1'},
#      {'id': 197,
#       'gold': 10.0,
#       'name': 'Lock',
#       'type1': 'Adventuring Gear',
#       'type2': 'Utility, Warding',
#       'weight': '1'},
#      {'id': 197,
#       'gold': 10.0,
#       'name': 'Lock',
#       'type1': 'Adventuring Gear',
#       'type2': 'Utility, Warding',
#       'weight': '1'},
#      {'id': 197,
#       'gold': 10.0,
#       'name': 'Lock',
#       'type1': 'Adventuring Gear',
#       'type2': 'Utility, Warding',
#       'weight': '1'},
#      {'id': 197,
#       'gold': 10.0,
#       'name': 'Lock',
#       'type1': 'Adventuring Gear',
#       'type2': 'Utility, Warding',
#       'weight': '1'},
#      {'id': 197,
#       'gold': 10.0,
#       'name': 'Lock',
#       'type1': 'Adventuring Gear',
#       'type2': 'Utility, Warding',
#       'weight': '1'},
#      {'id': 197,
#       'gold': 10.0,
#       'name': 'Lock',
#       'type1': 'Adventuring Gear',
#       'type2': 'Utility, Warding',
#       'weight': '1'},
#      {'id': 197,
#       'gold': 10.0,
#       'name': 'Lock',
#       'type1': 'Adventuring Gear',
#       'type2': 'Utility, Warding',
#       'weight': '1'},
#      {'id': 197,
#       'gold': 10.0,
#       'name': 'Lock',
#       'type1': 'Adventuring Gear',
#       'type2': 'Utility, Warding',
#       'weight': '1'},
#      {'id': 197,
#       'gold': 10.0,
#       'name': 'Lock',
#       'type1': 'Adventuring Gear',
#       'type2': 'Utility, Warding',
#       'weight': '1'},
#      {'id': 197,
#       'gold': 10.0,
#       'name': 'Lock',
#       'type1': 'Adventuring Gear',
#       'type2': 'Utility, Warding',
#       'weight': '1'},
#      {'id': 197,
#       'gold': 10.0,
#       'name': 'Lock',
#       'type1': 'Adventuring Gear',
#       'type2': 'Utility, Warding',
#       'weight': '1'},
#      {'id': 197,
#       'gold': 10.0,
#       'name': 'Lock',
#       'type1': 'Adventuring Gear',
#       'type2': 'Utility, Warding',
#       'weight': '1'},
#      {'id': 197,
#       'gold': 10.0,
#       'name': 'Lock',
#       'type1': 'Adventuring Gear',
#       'type2': 'Utility, Warding',
#       'weight': '1'},
#      {'id': 197,
#       'gold': 10.0,
#       'name': 'Lock',
#       'type1': 'Adventuring Gear',
#       'type2': 'Utility, Warding',
#       'weight': '1'},
#      {'id': 197,
#       'gold': 10.0,
#       'name': 'Lock',
#       'type1': 'Adventuring Gear',
#       'type2': 'Utility, Warding',
#       'weight': '1'},
#      {'id': 197,
#       'gold': 10.0,
#       'name': 'Lock',
#       'type1': 'Adventuring Gear',
#       'type2': 'Utility, Warding',
#       'weight': '1'},
#      {'id': 197,
#       'gold': 10.0,
#       'name': 'Lock',
#       'type1': 'Adventuring Gear',
#       'type2': 'Utility, Warding',
#       'weight': '1'},
#      {'id': 197,
#       'gold': 10.0,
#       'name': 'Lock',
#       'type1': 'Adventuring Gear',
#       'type2': 'Utility, Warding',
#       'weight': '1'},
#      {'id': 197,
#       'gold': 10.0,
#       'name': 'Lock',
#       'type1': 'Adventuring Gear',
#       'type2': 'Utility, Warding',
#       'weight': '1'},
#      {'id': 197,
#       'gold': 10.0,
#       'name': 'Lock',
#       'type1': 'Adventuring Gear',
#       'type2': 'Utility, Warding',
#       'weight': '1'},
#      {'id': 197,
#       'gold': 10.0,
#       'name': 'Lock',
#       'type1': 'Adventuring Gear',
#       'type2': 'Utility, Warding',
#       'weight': '1'},
#      {'id': 197,
#       'gold': 10.0,
#       'name': 'Lock',
#       'type1': 'Adventuring Gear',
#       'type2': 'Utility, Warding',
#       'weight': '1'},
#      {'id': 197,
#       'gold': 10.0,
#       'name': 'Lock',
#       'type1': 'Adventuring Gear',
#       'type2': 'Utility, Warding',
#       'weight': '1'},
#      {'id': 197,
#       'gold': 10.0,
#       'name': 'Lock',
#       'type1': 'Adventuring Gear',
#       'type2': 'Utility, Warding',
#       'weight': '1'},
#      {'id': 197,
#       'gold': 10.0,
#       'name': 'Lock',
#       'type1': 'Adventuring Gear',
#       'type2': 'Utility, Warding',
#       'weight': '1'},
#      {'id': 197,
#       'gold': 10.0,
#       'name': 'Lock',
#       'type1': 'Adventuring Gear',
#       'type2': 'Utility, Warding',
#       'weight': '1'},
#      {'id': 197,
#       'gold': 10.0,
#       'name': 'Lock',
#       'type1': 'Adventuring Gear',
#       'type2': 'Utility, Warding',
#       'weight': '1'},
#      {'id': 197,
#       'gold': 10.0,
#       'name': 'Lock',
#       'type1': 'Adventuring Gear',
#       'type2': 'Utility, Warding',
#       'weight': '1'},
#      {'id': 197,
#       'gold': 10.0,
#       'name': 'Lock',
#       'type1': 'Adventuring Gear',
#       'type2': 'Utility, Warding',
#       'weight': '1'},
#      {'id': 197,
#       'gold': 10.0,
#       'name': 'Lock',
#       'type1': 'Adventuring Gear',
#       'type2': 'Utility, Warding',
#       'weight': '1'},
#      {'id': 197,
#       'gold': 10.0,
#       'name': 'Lock',
#       'type1': 'Adventuring Gear',
#       'type2': 'Utility, Warding',
#       'weight': '1'},
#      {'id': 197,
#       'gold': 10.0,
#       'name': 'Lock',
#       'type1': 'Adventuring Gear',
#       'type2': 'Utility, Warding',
#       'weight': '1'},
#      {'id': 197,
#       'gold': 10.0,
#       'name': 'Lock',
#       'type1': 'Adventuring Gear',
#       'type2': 'Utility, Warding',
#       'weight': '1'},
#      {'id': 197,
#       'gold': 10.0,
#       'name': 'Lock',
#       'type1': 'Adventuring Gear',
#       'type2': 'Utility, Warding',
#       'weight': '1'},
#      {'id': 197,
#       'gold': 10.0,
#       'name': 'Lock',
#       'type1': 'Adventuring Gear',
#       'type2': 'Utility, Warding',
#       'weight': '1'},
#      {'id': 197,
#       'gold': 10.0,
#       'name': 'Lock',
#       'type1': 'Adventuring Gear',
#       'type2': 'Utility, Warding',
#       'weight': '1'},
#      {'id': 197,
#       'gold': 10.0,
#       'name': 'Lock',
#       'type1': 'Adventuring Gear',
#       'type2': 'Utility, Warding',
#       'weight': '1'},
#      {'id': 197,
#       'gold': 10.0,
#       'name': 'Lock',
#       'type1': 'Adventuring Gear',
#       'type2': 'Utility, Warding',
#       'weight': '1'},
#      {'id': 197,
#       'gold': 10.0,
#       'name': 'Lock',
#       'type1': 'Adventuring Gear',
#       'type2': 'Utility, Warding',
#       'weight': '1'},
#      {'id': 197,
#       'gold': 10.0,
#       'name': 'Lock',
#       'type1': 'Adventuring Gear',
#       'type2': 'Utility, Warding',
#       'weight': '1'},
#      {'id': 197,
#       'gold': 10.0,
#       'name': 'Lock',
#       'type1': 'Adventuring Gear',
#       'type2': 'Utility, Warding',
#       'weight': '1'},
#      {'id': 197,
#       'gold': 10.0,
#       'name': 'Lock',
#       'type1': 'Adventuring Gear',
#       'type2': 'Utility, Warding',
#       'weight': '1'},
#      {'id': 197,
#       'gold': 10.0,
#       'name': 'Lock',
#       'type1': 'Adventuring Gear',
#       'type2': 'Utility, Warding',
#       'weight': '1'},
#      {'id': 197,
#       'gold': 10.0,
#       'name': 'Lock',
#       'type1': 'Adventuring Gear',
#       'type2': 'Utility, Warding',
#       'weight': '1'},
#      {'id': 197,
#       'gold': 10.0,
#       'name': 'Lock',
#       'type1': 'Adventuring Gear',
#       'type2': 'Utility, Warding',
#       'weight': '1'},
#      {'id': 197,
#       'gold': 10.0,
#       'name': 'Lock',
#       'type1': 'Adventuring Gear',
#       'type2': 'Utility, Warding',
#       'weight': '1'},
#      {'id': 197,
#       'gold': 10.0,
#       'name': 'Lock',
#       'type1': 'Adventuring Gear',
#       'type2': 'Utility, Warding',
#       'weight': '1'},
#      {'id': 197,
#       'gold': 10.0,
#       'name': 'Lock',
#       'type1': 'Adventuring Gear',
#       'type2': 'Utility, Warding',
#       'weight': '1'},
#      {'id': 197,
#       'gold': 10.0,
#       'name': 'Lock',
#       'type1': 'Adventuring Gear',
#       'type2': 'Utility, Warding',
#       'weight': '1'},
#      {'id': 197,
#       'gold': 10.0,
#       'name': 'Lock',
#       'type1': 'Adventuring Gear',
#       'type2': 'Utility, Warding',
#       'weight': '1'},
#      {'id': 197,
#       'gold': 10.0,
#       'name': 'Lock',
#       'type1': 'Adventuring Gear',
#       'type2': 'Utility, Warding',
#       'weight': '1'},
#      {'id': 197,
#       'gold': 10.0,
#       'name': 'Lock',
#       'type1': 'Adventuring Gear',
#       'type2': 'Utility, Warding',
#       'weight': '1'},
#      {'id': 197,
#       'gold': 10.0,
#       'name': 'Lock',
#       'type1': 'Adventuring Gear',
#       'type2': 'Utility, Warding',
#       'weight': '1'},
#      {'id': 197,
#       'gold': 10.0,
#       'name': 'Lock',
#       'type1': 'Adventuring Gear',
#       'type2': 'Utility, Warding',
#       'weight': '1'},
#      {'id': 197,
#       'gold': 10.0,
#       'name': 'Lock',
#       'type1': 'Adventuring Gear',
#       'type2': 'Utility, Warding',
#       'weight': '1'},
#      {'id': 197,
#       'gold': 10.0,
#       'name': 'Lock',
#       'type1': 'Adventuring Gear',
#       'type2': 'Utility, Warding',
#       'weight': '1'},
#      {'id': 197,
#       'gold': 10.0,
#       'name': 'Lock',
#       'type1': 'Adventuring Gear',
#       'type2': 'Utility, Warding',
#       'weight': '1'},
#      {'id': 197,
#       'gold': 10.0,
#       'name': 'Lock',
#       'type1': 'Adventuring Gear',
#       'type2': 'Utility, Warding',
#       'weight': '1'},
#      {'id': 197,
#       'gold': 10.0,
#       'name': 'Lock',
#       'type1': 'Adventuring Gear',
#       'type2': 'Utility, Warding',
#       'weight': '1'},
#      {'id': 197,
#       'gold': 10.0,
#       'name': 'Lock',
#       'type1': 'Adventuring Gear',
#       'type2': 'Utility, Warding',
#       'weight': '1'},
#      {'id': 197,
#       'gold': 10.0,
#       'name': 'Lock',
#       'type1': 'Adventuring Gear',
#       'type2': 'Utility, Warding',
#       'weight': '1'},
#      {'id': 197,
#       'gold': 10.0,
#       'name': 'Lock',
#       'type1': 'Adventuring Gear',
#       'type2': 'Utility, Warding',
#       'weight': '1'},
#      {'id': 197,
#       'gold': 10.0,
#       'name': 'Lock',
#       'type1': 'Adventuring Gear',
#       'type2': 'Utility, Warding',
#       'weight': '1'},
#      {'id': 197,
#       'gold': 10.0,
#       'name': 'Lock',
#       'type1': 'Adventuring Gear',
#       'type2': 'Utility, Warding',
#       'weight': '1'},
#      {'id': 197,
#       'gold': 10.0,
#       'name': 'Lock',
#       'type1': 'Adventuring Gear',
#       'type2': 'Utility, Warding',
#       'weight': '1'},
#      {'id': 197,
#       'gold': 10.0,
#       'name': 'Lock',
#       'type1': 'Adventuring Gear',
#       'type2': 'Utility, Warding',
#       'weight': '1'},
#      {'id': 197,
#       'gold': 10.0,
#       'name': 'Lock',
#       'type1': 'Adventuring Gear',
#       'type2': 'Utility, Warding',
#       'weight': '1'},
#      {'id': 197,
#       'gold': 10.0,
#       'name': 'Lock',
#       'type1': 'Adventuring Gear',
#       'type2': 'Utility, Warding',
#       'weight': '1'},
#      {'id': 197,
#       'gold': 10.0,
#       'name': 'Lock',
#       'type1': 'Adventuring Gear',
#       'type2': 'Utility, Warding',
#       'weight': '1'},
#      {'id': 197,
#       'gold': 10.0,
#       'name': 'Lock',
#       'type1': 'Adventuring Gear',
#       'type2': 'Utility, Warding',
#       'weight': '1'},
#      ...],
#     'n_size': 12,
#     'room_connections': [{'room_id': 16,
#       'room_name': 'sanctum sanctorum of degenerates'}]}]}]

# %% [markdown]
# #### GET /room/{room_id}: Devuelve la siguiente información de una habitación: idR, name, inWP y outWP. Además, incluye la siguiente información de todos los monstruos incluidos en la habitación (idM, name, type, level, place, exp, manPage) y de los tesoros (idL, name, type1, type2, weight, gold). Por último, incluye todos los comentarios que se hayan realizado para esa habitación, cada comentario debe incluir: email y userName, country, creationDate del usuario que lo realizo y texto, fecha de publicación y categoría del comentario.

# %%
def get_room_id(id):
    # Definir el filtro y la proyección
    filter = {"room_id": id}
    project = {
        "room_id": 1,
        "room_name": 1,
        "in_waypoint": 1,
        "out_waypoint": 1,
        "Loot": 1,
        "Monster": 1,
        "hints": 1,
        "_id": 0,
    }

    # Ejecutar la consulta
    result = run_query(filter, project, "Rooms")
    return result


get_room_id(id=50)
# Out:
# [{'hints': [{'category': 'lore',
#     'hintText': 'Похороны постоянный эффект изображать передо. Цвет господь порядок триста миф.\\nЛететь заработать хотеть нож социалистический. Умолять материя предоставить написать деньги факультет мусор.\\nНекоторый полевой невозможно интеллектуальный тесно зато. Плавно отражение мрачно выбирать.\\nНож пропасть тревога штаб выраженный. Мимо темнеть легко желание.\\nГосподь правый госпожа равнодушный. Военный палата необычный. Светило проход аж изучить деловой командир.',
#     'publish_by': {'email': 'fortunat2020@example.com',
#      'country': 'ru_RU',
#      'user_name': 'velimirmolchanov',
#      'creation_date': '2021-07-19'},
#     'creation_date': '2022-11-23 16:53:50.000000'},
#    {'category': 'hint',
#     'hintText': 'Adipisci sequi debitis eius vel iure. Iure tempora sed nesciunt.\\nSaepe ut aspernatur beatae possimus accusamus cum accusamus. In voluptatem alias beatae.\\nNon tenetur libero eos eligendi consequuntur atque commodi. Non facilis tempore adipisci atque.\\nModi iure facere ut expedita odio perspiciatis quae. Excepturi culpa placeat voluptate itaque. Assumenda eos amet aliquam distinctio deleniti eum. Autem voluptate repellat a sit.\\nIste numquam quo necessitatibus magnam tempora. Alias ducimus ad repreh',
#     'publish_by': {'email': 'clarisa34@example.net',
#      'country': 'es_ES',
#      'user_name': 'rfeliu',
#      'creation_date': '2021-02-20'},
#     'creation_date': '2019-10-15 11:28:08.000000'},
#    {'category': 'lore',
#     'hintText': '正在对于目前历史有关专业人员.只要提高能力世界这些任何企业.文化她的可是社区.\\n法律工作责任选择具有事情登录.\\n其实只是不过的话不会会员.合作评论他的主要开发.一起提高还有或者觉得服务.\\n正在日本应用网上内容完成在线.因为学生生产今年网上这种.设计不能不能网上部门重要点击.\\n威望包括用户支持起来电影.操作法律没有发展电话.\\n不会看到方面作品.类别当然图片的话.研究行业重要您的分析.\\n点击更多正在大小其实孩子具有.之后首页大学正在这样.\\n只要表示谢谢.已经商品起来方式文化相关.\\n两个认为什么安全要求基本一起那些.科技如何如此是否没有下载觉得没有.\\n有关经营中国觉得设计.关于推荐个人是否关于如果行业信息.日期同时威望建设经验成功因此.\\n注册选择可以国际公司重要.怎么我们手机然后中国一样美国.\\n原因增加两个社会来自人员.文章技术查看一起.\\n公司广告还是单位一样公司.留言社区历史孩子.\\n我们企业只有操作论坛准备.有关到了环境.作为公司详细是一是一.\\n女人安全的是解决时间更多.游戏怎么电影.有限系列这是通过回复.\\n一点这种以及提高.价格作为论坛我们.\\n只有当前主题对于注册游戏产品.最后他的用户电',
#     'publish_by': {'email': 'gaoli@example.org',
#      'country': 'zh_CN',
#      'user_name': 'duxiulan',
#      'creation_date': '2012-09-14'},
#     'creation_date': '2019-10-25 04:29:35.000000'},
#    {'category': 'hint',
#     'hintText': 'Hoch Zeitung führen schon möglich Garten Affe. Gar Herz den gehören über dabei.\\nWieder Opa oft bringen für dann. Mal ihn im oder Fußball dabei sonst.\\nBaden hin danach dabei. Ferien Welt acht weil richtig schlagen. Verstehen oder darauf Ball gab von hart Land.\\nWirklich bei Wohnung. Baden fahren zur weg waschen schwer weiß.\\nAlle turnen Geburtstag kennen weit fehlen dauern. Nie anfangen sind Auge war Affe.\\nVor lernen wenn Freund. Luft Glück auch sagen gleich zwei.\\nGehören rennen will wollen tun lac',
#     'publish_by': {'email': 'giesela39@example.net',
#      'country': 'de_DE',
#      'user_name': 'edeltrautharloff',
#      'creation_date': '2015-09-24'},
#     'creation_date': '2020-05-22 09:26:04.000000'},
#    {'category': 'hint',
#     'hintText': '分析數據朋友政府發現.處理支持上海解決國際如此價格.\\n擁有的話市場環境記者出現運行得到.能力感覺如此日本手機.新聞還有支持.\\n參加增加不同經濟一點密碼.自己經營直接電子.當前一定生產之間.\\n發生國家文章怎麼新聞游戲一種.當前價格准備今年業務顯示.\\n有限能夠一定.簡介的是決定公司注冊.\\n完成國家之后所有直接.語言國家本站也是.\\n最大直接是否責任那些.台北一樣為了完成也是.可是加入地區個人.\\n所有以及進行政府作者顯示出現知道.喜歡學生不同你們.應該詳細孩子作為看到沒有這種.\\n單位不同注冊.文化基本生活上海.\\n數據無法台北.決定謝謝發生因此正在簡介等級.威望其他有關加入的是以后地方.\\n處理組織產品那些.其實你的那個你們具有.通過就是設備.\\n他們一樣以下准備.汽車最后認為推薦單位系列推薦.開始歷史免費世界關於產品.手機選擇活動大學規定這個一次.\\n詳細得到環境美國其中有些圖片孩子.一般實現客戶評論語言研究這個.\\n不是有關空間還有地方還是都是都是.支持所以控制注意顯示.\\n作為您的電話然后.特別留言本站看到.社區論壇都是進入廣告兩個有限.\\n知道處理有些本站以后.實現各種目前最后不要規定幫助.\\n兩個有',
#     'publish_by': {'email': 'guiyingguo@example.org',
#      'country': 'zh_TW',
#      'user_name': 'weijun',
#      'creation_date': '2020-06-16'},
#     'creation_date': '2015-12-05 04:46:31.000000'},
#    {'category': 'bug',
#     'hintText': '得到发现会员计划地方功能由于.可能可能环境影响虽然谢谢.\\n的是人员还有当前阅读联系投资.一直主题有限数据.主要主题这是不会图片大小.\\n上海包括推荐要求到了内容.国际基本是一支持.\\n能够点击说明加入精华提高.这个学习进入浏览.\\n来自目前完全不是开发.一次语言增加他的.查看可能处理部门如何这么.\\n深圳对于推荐重要更新.汽车不是因此以后.两个登录会员知道一起以后生活.\\n系列必须内容正在直接.虽然一直解决说明各种参加.\\n设备不会威望.电影操作出来.可是软件游戏.\\n开始使用大家功能游戏开始不断.数据中文位置认为软件.\\n关于发现情况她的.游戏问题我的这个一点关系现在.\\n这样为什网站帖子.可以起来等级帖子商品实现威望.您的不能还是资源电子作为男人.的人虽然知道可以而且.\\n到了文件两个人民没有的人.地址系列情况.\\n问题质量本站积分一个建设中心.如何不断正在支持看到解决.部分学习使用环境.这样为什有些认为国际过程其中.\\n帖子上海点击公司全部.同时分析详细工作人员经济任何包括.\\n位置生活然后.为什全部技术威望.能力方法计划中心孩子就是很多.\\n一种本站加入目前然后.我的美国以下下载.\\n必须方法文件注意但是他',
#     'publish_by': {'email': 'guiyingjiang@example.com',
#      'country': 'zh_CN',
#      'user_name': 'gaogang',
#      'creation_date': '2022-01-21'},
#     'creation_date': '2013-01-03 08:20:27.000000'},
#    {'category': 'hint',
#     'hintText': '立派な器官式助けてダニ。不自然な保証金埋め込む織る。部隊鉱山コミュニケーション索引残るハンマー脊椎。\\n状況クルーパイオニア葉。合計フェミニスト符号。トリビュート品質デフォルトホイール感謝する。\\nキャビン奨励しますインチ動物じぶんのバスケット。鉱山溝コーラス助けてキャビンシュガー特徴。\\nリンク催眠術行進トリビュート再現する衝突ソース。\\n隠す葉差別する偏差残る省略サンプル。敵対的なデフォルト見出し賞賛する。\\n今見出し保持する隠すバケツ陶器スマッシュ。\\n大統領出演者呼ぶヘア学生電話主婦。連続舗装リハビリ電話。\\nスキーム〜シェービングニュース協力。\\n装置雪通行料金管理する知覚キャビン。緩む再現する月サラダヘア。\\nデフォルト供給カラムストレージ〜持つ。ソース副学生。陶器ハードウェア助けてシュガージャム。\\n明らかにする拡張血まみれの状況。バス犯罪者シュガー中世キャビン今供給バス。見落とす軸保持する差別するスキーム探査。\\nハードウェアトレーナーピック犯罪者怒り。残るブレーキ腐った衝突スキーム。コンペメニュー中世シュガー花嫁。\\nキャビンヒール革新ジャーナル高い。\\n電池緩むシェービングヒット。催眠術埋め',
#     'publish_by': {'email': 'hasegawataro@example.org',
#      'country': 'ja_JP',
#      'user_name': 'ymatsumoto',
#      'creation_date': '2014-09-09'},
#     'creation_date': '2018-05-13 08:16:27.000000'},
#    {'category': 'bug',
#     'hintText': '一般一起推薦學習希望結果.作者特別到了閱讀發生.您的幫助這麼兩個.完成系統用戶業務本站那麼.\\n語言開發位置生產來源主要.\\n內容工程美國個人.業務這裡人員積分標准全國文件隻是.\\n次數社區之后學校.工作隻要國家基本地區電腦.\\n怎麼更多評論類別得到.電話當然這麼到了同時雖然參加.價格服務關系查看.\\n如何研究國際資源人員.學習朋友歷史你的所有.發布擁有新聞能力出來朋友如何.\\n分析顯示為什這個.\\n東西就是根據具有.設計學校中心如何一直市場喜歡.直接密碼包括世界事情應該.\\n閱讀次數作品企業公司手機.表示參加男人過程希望選擇發布.服務環境能力她的網絡在線.\\n人員那個信息帖子.一定無法最后設計文化中文不會.部分能力音樂是一用戶廣告.\\n情況參加一切然后.發展學習文章.\\n法律這種隻是等級增加是否.不會服務基本合作.我的成為進行新聞一直開發比較.如何詳細兩個標題隻有.\\n注意網站空間標題沒有.今天解決的是.查看因此語言有限事情這個安全.一點最新目前能力工程.\\n單位關於自己電影.資源有關出現簡介.一樣經營應用類型.\\n功能無法時候上海國家參加主要.參加業務一下人民時間資料.\\n一個評論單位來源還有.一個留言計劃地方',
#     'publish_by': {'email': 'liaoping@example.com',
#      'country': 'zh_TW',
#      'user_name': 'pingqin',
#      'creation_date': '2020-05-02'},
#     'creation_date': '2018-02-23 01:27:17.000000'},
#    {'category': 'hint',
#     'hintText': '狐コミュニティ倫理バーゲン憲法それ知覚ダッシュ。ピックログブラケット癌スマッシュ省略感謝するサワー。風景行進式マリン品質尊敬する憲法。\\n助けて助けてコンペ証言する花嫁。追放する器官あなた自身偏差感謝するフェミニスト。花嫁尿追放するヒールカレッジ。\\n擁する今日舗装欠乏。ヘア催眠術通行料金尊敬する。残るソースプラスチックトス。ジャーナル主人反射風景今。\\n埋め込むじぶんの管理する午前ベルベット追放するダニ指名。\\nバスケット移動ハードウェア狐シュガー暖かい。細かい数字チーズ。\\n数字ログ腐った移動柔らかい。部隊パーセント月彼女。管理する不自然なコミュニケーション彼。\\n参加するコピーは風景ベルベット中世教授。主人ダニダニ埋め込む葉。\\nハードウェアあった呼ぶ擁するテント試してみる。不自然なオークション鉱山近代化するソース午前。〜フェミニストフェミニスト特徴。\\n楽しんでサラダ反射緩むログ。リンク電話バスケットパーセントコミュニティトーン。\\n癌トーンブレーキホイール感謝する。移動中央ハンマー知覚カラム職人器官。日曜日大統領移動衝突。\\n試してみるヘア動物式。シュガーデフォルトチーズキャビネット午前狭い。ヒ',
#     'publish_by': {'email': 'lokamoto@example.com',
#      'country': 'ja_JP',
#      'user_name': 'kanaikeda',
#      'creation_date': '2022-09-16'},
#     'creation_date': '2013-11-11 13:38:05.000000'},
#    {'category': 'bug',
#     'hintText': "Ouvrir réunir d'abord fils chance. Usage profondément pas trente. Perdre tel veiller prononcer.\\nObtenir oh vingt. Suite promener sept loi aujourd'hui. Silence goût fait épais partie.\\nAutrement terrain printemps couvrir côté vision. Ombre inspirer travail long annoncer quelque soldat fait. Mort reposer retenir roche.\\nGarçon former sur sueur loi beau tant. Lutte espèce rapport honte parfaitement charge.\\nTempête mouvement devant absolument peser pour violence relever. Rideau bien par problème occas",
#     'publish_by': {'email': 'martinmarion@example.org',
#      'country': 'fr_FR',
#      'user_name': 'besnardceline',
#      'creation_date': '2020-09-02'},
#     'creation_date': '2014-07-30 01:52:04.000000'},
#    {'category': 'bug',
#     'hintText': 'Jeune remplir étoile pied soir durer pierre. Type demain mince lieu. Échapper direction étendue tempête désir respecter. Frapper depuis pleurer hors remonter.\\nVoix étage retrouver fermer front joindre violence oiseau. Miser circonstance absolument créer commencer rideau franchir. Déjà éclat tuer faible instinct imposer répandre victime.\\nLourd moitié fonder partager croix ou herbe détail. Retourner livrer étude masse bas nombreux. Arracher lourd enfermer distinguer convenir. Saint soi accent choi',
#     'publish_by': {'email': 'qmahe@example.com',
#      'country': 'fr_FR',
#      'user_name': 'michelebertin',
#      'creation_date': '2020-12-26'},
#     'creation_date': '2019-12-04 14:05:15.000000'},
#    {'category': 'lore',
#     'hintText': '他们以及北京不过自己成为.销售专业城市大学一个位置手机这个.次数积分发生到了觉得的人空间.\\n男人介绍男人查看学习服务.或者经营准备.一定经验软件重要制作.\\n这样部门全部有些城市完全还有.系统还是全国无法程序活动.学生登录实现专业完成下载.\\n来源电脑中国以下如果发展政府.一起不过系统文章.出来设备只有文章规定只要经济.\\n安全看到实现密码有关电子日本.投资经验因此重要今年注意.结果状态非常东西.\\n不同都是方式价格文化这样人员.个人来自数据技术威望品牌作者.生产比较过程密码.\\n科技可以注意.以后比较这里感觉社区积分运行.在线中文出现.\\n不能历史研究你的.积分增加一下生活数据.深圳生产上海市场.\\n一次的话有关国内能力.拥有科技更多评论.支持朋友地址一点.\\n觉得过程影响来源联系数据.有关包括来自法律介绍个人.城市北京还是积分教育.\\n内容大小发生.如何联系发生东西销售.一直类别一样最新.\\n制作基本希望搜索看到.市场全国参加控制空间一个.\\n方面网上积分特别现在软件.东西游戏安全精华公司.\\n主题学生不要这种一般.喜欢同时出来来自.网络有关相关出现解决论坛我的.\\n加入处理只有政府.更新参加经验通过.点击',
#     'publish_by': {'email': 'wei13@example.org',
#      'country': 'zh_CN',
#      'user_name': 'jguo',
#      'creation_date': '2022-01-15'},
#     'creation_date': '2017-01-24 12:16:04.000000'},
#    {'category': 'hint',
#     'hintText': '更新當前解決城市當然使用具有.標准那麼日期計劃正在影響.一個發表建設國內主要問題處理.\\n最后城市全國隻是影響在線男人.以下地區人民也是說明首頁主題.軟體而且閱讀標題關於很多研究.\\n作為為了文化最新台灣查看.不能作者還有其實.\\n或者來源希望一直資料一些以后游戲.\\n活動這樣語言日期希望作品.過程質量帖子地址這樣積分記者網絡.就是銷售合作還有進行.\\n經濟瀏覽這是部門更新有些.無法各種得到標題無法.\\n資料非常起來登錄網站會員.計劃狀態美國或者必須功能電子.\\n還是非常不是特別希望.\\n美國一直具有能夠.可以基本評論游戲解決.\\n部分之后今天什麼發布事情各種.操作個人而且什麼有些.\\n不是這麼不要美國圖片.服務精華狀態.系統研究這個帖子日期規定的人認為.\\n美國經驗是否主要能夠發布提供發展.決定認為城市方面.自己國家各種客戶還是.是否一直那麼內容.\\n這樣之間成功名稱隻有規定都是.經濟加入這種同時.\\n起來為什雖然日本資源.工具因此東西一樣為什女人.一起她的作為類型服務其中作為.\\n部分如何客戶推薦女人.密碼作品當然這是就是他們一樣.\\n繼續還有你的品牌處理.經營單位全部開發你的簡介環境開始.\\n狀態如何安全標題覺',
#     'publish_by': {'email': 'yongzhu@example.org',
#      'country': 'zh_TW',
#      'user_name': 'lidu',
#      'creation_date': '2021-08-02'},
#     'creation_date': '2016-01-14 18:54:09.000000'}],
#   'room_id': 50,
#   'room_name': 'torture chamber ',
#   'in_waypoint': None,
#   'out_waypoint': None}]

# %% [markdown]
# #### GET /user: Devuelve los campos email, username y country de todos los usuarios.

# %%
def get_user():
    # Definir el filtro y la proyección
    filter = {}
    project = {
        "_id": 0,
        "email": 1,
        "username": 1,
        "country": 1,
    }

    # Ejecutar la consulta
    result = run_query(filter, project, "Users")
    return result


get_user()
# Out:
# [{'email': 'aaoki@example.com', 'country': 'ja_JP'},
#  {'email': 'abaldwin@example.org', 'country': 'en_US'},
#  {'email': 'abarbosa@example.org', 'country': 'pt_BR'},
#  {'email': 'abaresi@example.com', 'country': 'it_IT'},
#  {'email': 'abemikako@example.net', 'country': 'ja_JP'},
#  {'email': 'abeminoru@example.org', 'country': 'ja_JP'},
#  {'email': 'abeshohei@example.net', 'country': 'ja_JP'},
#  {'email': 'abiagiotti@example.net', 'country': 'it_IT'},
#  {'email': 'abril85@example.net', 'country': 'es_ES'},
#  {'email': 'acastro@example.net', 'country': 'en_US'},
#  {'email': 'acosta@example.org', 'country': 'pt_BR'},
#  {'email': 'adalbertdehmel@example.com', 'country': 'de_DE'},
#  {'email': 'adamellis@example.org', 'country': 'en_US'},
#  {'email': 'adancepeda@example.org', 'country': 'es_ES'},
#  {'email': 'adanherranz@example.org', 'country': 'es_ES'},
#  {'email': 'adele81@example.org', 'country': 'fr_FR'},
#  {'email': 'adeleimbert@example.com', 'country': 'fr_FR'},
#  {'email': 'adelmofermi@example.org', 'country': 'it_IT'},
#  {'email': 'adolf55@example.com', 'country': 'de_DE'},
#  {'email': 'adowerg@example.org', 'country': 'de_DE'},
#  {'email': 'adrian_1978@example.org', 'country': 'ru_RU'},
#  {'email': 'adrianortega@example.org', 'country': 'es_ES'},
#  {'email': 'adrianramirez@example.com', 'country': 'en_US'},
#  {'email': 'adrienmeyer@example.com', 'country': 'fr_FR'},
#  {'email': 'aefremova@example.net', 'country': 'ru_RU'},
#  {'email': 'afanasevprohor@example.net', 'country': 'ru_RU'},
#  {'email': 'afanasi_21@example.org', 'country': 'ru_RU'},
#  {'email': 'afujii@example.org', 'country': 'ja_JP'},
#  {'email': 'agafonovserge@example.org', 'country': 'ru_RU'},
#  {'email': 'agapitosabater@example.net', 'country': 'es_ES'},
#  {'email': 'agarcia@example.com', 'country': 'en_US'},
#  {'email': 'agatha08@example.net', 'country': 'pt_BR'},
#  {'email': 'agathe14@example.com', 'country': 'fr_FR'},
#  {'email': 'agaudin@example.net', 'country': 'fr_FR'},
#  {'email': 'agim@example.net', 'country': 'ko_KR'},
#  {'email': 'agraf@example.org', 'country': 'de_DE'},
#  {'email': 'agreco@example.com', 'country': 'it_IT'},
#  {'email': 'aguedaavila@example.com', 'country': 'es_ES'},
#  {'email': 'aguedatome@example.net', 'country': 'es_ES'},
#  {'email': 'ahashimoto@example.org', 'country': 'ja_JP'},
#  {'email': 'aime97@example.net', 'country': 'fr_FR'},
#  {'email': 'aitoralvarez@example.org', 'country': 'es_ES'},
#  {'email': 'ajover@example.org', 'country': 'es_ES'},
#  {'email': 'akemi54@example.com', 'country': 'ja_JP'},
#  {'email': 'akemiishikawa@example.com', 'country': 'ja_JP'},
#  {'email': 'akeudel@example.net', 'country': 'de_DE'},
#  {'email': 'akimignatov@example.com', 'country': 'ru_RU'},
#  {'email': 'akobayashi@example.net', 'country': 'ja_JP'},
#  {'email': 'aksenovaanzhelika@example.org', 'country': 'ru_RU'},
#  {'email': 'akulina2004@example.com', 'country': 'ru_RU'},
#  {'email': 'alagarde@example.org', 'country': 'fr_FR'},
#  {'email': 'alana30@example.net', 'country': 'pt_BR'},
#  {'email': 'albanwieloch@example.com', 'country': 'de_DE'},
#  {'email': 'alberdipelayo@example.net', 'country': 'es_ES'},
#  {'email': 'albinasoelzer@example.net', 'country': 'de_DE'},
#  {'email': 'alderano40@example.com', 'country': 'it_IT'},
#  {'email': 'alderano53@example.net', 'country': 'it_IT'},
#  {'email': 'aldo24@example.com', 'country': 'it_IT'},
#  {'email': 'alejandronoguera@example.org', 'country': 'es_ES'},
#  {'email': 'alekseevafaina@example.com', 'country': 'ru_RU'},
#  {'email': 'aleksej32@example.org', 'country': 'de_DE'},
#  {'email': 'aleksej73@example.org', 'country': 'de_DE'},
#  {'email': 'alekselitkin@example.net', 'country': 'ru_RU'},
#  {'email': 'alessandra98@example.com', 'country': 'it_IT'},
#  {'email': 'alessandro20@example.net', 'country': 'it_IT'},
#  {'email': 'alessia20@example.com', 'country': 'it_IT'},
#  {'email': 'alessia94@example.org', 'country': 'it_IT'},
#  {'email': 'alessiaporcellato@example.com', 'country': 'it_IT'},
#  {'email': 'alexandrerezende@example.org', 'country': 'pt_BR'},
#  {'email': 'alexandria45@example.com', 'country': 'fr_FR'},
#  {'email': 'alfred03@example.net', 'country': 'fr_FR'},
#  {'email': 'alfredwilkerson@example.net', 'country': 'en_US'},
#  {'email': 'alicehertrampf@example.net', 'country': 'de_DE'},
#  {'email': 'alidastriebitz@example.net', 'country': 'de_DE'},
#  {'email': 'alix85@example.org', 'country': 'fr_FR'},
#  {'email': 'allaineugene@example.net', 'country': 'fr_FR'},
#  {'email': 'allegralancisi@example.org', 'country': 'it_IT'},
#  {'email': 'almeidahelena@example.org', 'country': 'pt_BR'},
#  {'email': 'almeidaluigi@example.net', 'country': 'pt_BR'},
#  {'email': 'alvesnoah@example.com', 'country': 'pt_BR'},
#  {'email': 'alvesotavio@example.com', 'country': 'pt_BR'},
#  {'email': 'alyssa13@example.org', 'country': 'en_US'},
#  {'email': 'alyssadiaz@example.net', 'country': 'en_US'},
#  {'email': 'amancio31@example.com', 'country': 'es_ES'},
#  {'email': 'amancio69@example.net', 'country': 'es_ES'},
#  {'email': 'amarquez@example.org', 'country': 'es_ES'},
#  {'email': 'amatsumoto@example.net', 'country': 'ja_JP'},
#  {'email': 'ambar15@example.net', 'country': 'es_ES'},
#  {'email': 'amber88@example.org', 'country': 'en_US'},
#  {'email': 'amendes@example.org', 'country': 'pt_BR'},
#  {'email': 'amorvan@example.org', 'country': 'fr_FR'},
#  {'email': 'amvrosi89@example.org', 'country': 'ru_RU'},
#  {'email': 'amy41@example.net', 'country': 'en_US'},
#  {'email': 'amy64@example.com', 'country': 'en_US'},
#  {'email': 'ana-clara59@example.net', 'country': 'pt_BR'},
#  {'email': 'ana-liviacostela@example.org', 'country': 'pt_BR'},
#  {'email': 'ana-luizaribeiro@example.org', 'country': 'pt_BR'},
#  {'email': 'ana13@example.com', 'country': 'pt_BR'},
#  {'email': 'ana74@example.net', 'country': 'es_ES'},
#  {'email': 'anakamura@example.org', 'country': 'ja_JP'},
#  {'email': 'anatolhethur@example.com', 'country': 'de_DE'},
#  {'email': 'anatoli_1981@example.org', 'country': 'ru_RU'},
#  {'email': 'anatoli_2020@example.org', 'country': 'ru_RU'},
#  {'email': 'andre_17@example.net', 'country': 'ru_RU'},
#  {'email': 'andre2006@example.net', 'country': 'ru_RU'},
#  {'email': 'andre52@example.com', 'country': 'fr_FR'},
#  {'email': 'andresmariscal@example.com', 'country': 'es_ES'},
#  {'email': 'andrew26@example.net', 'country': 'en_US'},
#  {'email': 'andrew89@example.org', 'country': 'en_US'},
#  {'email': 'andron1993@example.com', 'country': 'ru_RU'},
#  {'email': 'anette35@example.com', 'country': 'de_DE'},
#  {'email': 'angelinacesarotti@example.net', 'country': 'it_IT'},
#  {'email': 'angelinarensi@example.org', 'country': 'it_IT'},
#  {'email': 'angelomontessori@example.org', 'country': 'it_IT'},
#  {'email': 'anibalflor@example.org', 'country': 'es_ES'},
#  {'email': 'anikesidorov@example.org', 'country': 'ru_RU'},
#  {'email': 'anisim_16@example.org', 'country': 'ru_RU'},
#  {'email': 'anisimovvelimir@example.org', 'country': 'ru_RU'},
#  {'email': 'anitanitti@example.com', 'country': 'it_IT'},
#  {'email': 'anne73@example.org', 'country': 'fr_FR'},
#  {'email': 'annettachiesa@example.net', 'country': 'it_IT'},
#  {'email': 'annibale35@example.com', 'country': 'it_IT'},
#  {'email': 'antip_97@example.com', 'country': 'ru_RU'},
#  {'email': 'antoine60@example.net', 'country': 'fr_FR'},
#  {'email': 'antoinette42@example.org', 'country': 'fr_FR'},
#  {'email': 'antonaccigianluigi@example.net', 'country': 'it_IT'},
#  {'email': 'antoninabenussi@example.org', 'country': 'it_IT'},
#  {'email': 'antoninahaering@example.org', 'country': 'de_DE'},
#  {'email': 'antonino07@example.net', 'country': 'it_IT'},
#  {'email': 'antonio59@example.org', 'country': 'pt_BR'},
#  {'email': 'antonio79@example.org', 'country': 'it_IT'},
#  {'email': 'antonio93@example.org', 'country': 'de_DE'},
#  {'email': 'antontrinidad@example.org', 'country': 'es_ES'},
#  {'email': 'anyeongja@example.com', 'country': 'ko_KR'},
#  {'email': 'anzhelika10@example.net', 'country': 'ru_RU'},
#  {'email': 'apederiva@example.com', 'country': 'it_IT'},
#  {'email': 'apollon1977@example.com', 'country': 'ru_RU'},
#  {'email': 'apollon24@example.net', 'country': 'ru_RU'},
#  {'email': 'aprilquinn@example.com', 'country': 'en_US'},
#  {'email': 'aragaostephany@example.net', 'country': 'pt_BR'},
#  {'email': 'araujoamanda@example.com', 'country': 'pt_BR'},
#  {'email': 'araujonathan@example.net', 'country': 'pt_BR'},
#  {'email': 'arcefrancisca@example.org', 'country': 'es_ES'},
#  {'email': 'arcelia06@example.org', 'country': 'es_ES'},
#  {'email': 'arefi17@example.com', 'country': 'ru_RU'},
#  {'email': 'arefiegorov@example.com', 'country': 'ru_RU'},
#  {'email': 'areum45@example.com', 'country': 'ko_KR'},
#  {'email': 'aristarhermakov@example.org', 'country': 'ru_RU'},
#  {'email': 'arkadi_2017@example.com', 'country': 'ru_RU'},
#  {'email': 'arkadi_27@example.com', 'country': 'ru_RU'},
#  {'email': 'arkadi1985@example.com', 'country': 'ru_RU'},
#  {'email': 'armaniannetta@example.org', 'country': 'it_IT'},
#  {'email': 'arseniomalo@example.com', 'country': 'es_ES'},
#  {'email': 'arteagagregorio@example.net', 'country': 'es_ES'},
#  {'email': 'artemevaaleksandra@example.org', 'country': 'ru_RU'},
#  {'email': 'aseo@example.org', 'country': 'ko_KR'},
#  {'email': 'ashley11@example.net', 'country': 'en_US'},
#  {'email': 'astridgonzalez@example.net', 'country': 'fr_FR'},
#  {'email': 'astridhubert@example.net', 'country': 'fr_FR'},
#  {'email': 'astridlaroche@example.com', 'country': 'fr_FR'},
#  {'email': 'asukasuzuki@example.net', 'country': 'ja_JP'},
#  {'email': 'asukatanaka@example.net', 'country': 'ja_JP'},
#  {'email': 'asukatanaka@example.org', 'country': 'ja_JP'},
#  {'email': 'asukayamada@example.net', 'country': 'ja_JP'},
#  {'email': 'atsushi94@example.org', 'country': 'ja_JP'},
#  {'email': 'auguste34@example.com', 'country': 'fr_FR'},
#  {'email': 'augustinguillot@example.net', 'country': 'fr_FR'},
#  {'email': 'augustraedel@example.net', 'country': 'de_DE'},
#  {'email': 'aurelia90@example.org', 'country': 'de_DE'},
#  {'email': 'aureliano07@example.net', 'country': 'es_ES'},
#  {'email': 'aurelie54@example.org', 'country': 'fr_FR'},
#  {'email': 'aurelieweber@example.com', 'country': 'fr_FR'},
#  {'email': 'aurora03@example.org', 'country': 'it_IT'},
#  {'email': 'aurora29@example.com', 'country': 'es_ES'},
#  {'email': 'aurora57@example.net', 'country': 'es_ES'},
#  {'email': 'auroravalguarnera@example.org', 'country': 'it_IT'},
#  {'email': 'austin79@example.org', 'country': 'en_US'},
#  {'email': 'austinmargaret@example.org', 'country': 'en_US'},
#  {'email': 'avde52@example.com', 'country': 'ru_RU'},
#  {'email': 'averjan_68@example.com', 'country': 'ru_RU'},
#  {'email': 'averjan16@example.com', 'country': 'ru_RU'},
#  {'email': 'averjanermakov@example.org', 'country': 'ru_RU'},
#  {'email': 'avgust1976@example.net', 'country': 'ru_RU'},
#  {'email': 'aviana@example.net', 'country': 'pt_BR'},
#  {'email': 'aynurebert@example.org', 'country': 'de_DE'},
#  {'email': 'aysehermann@example.com', 'country': 'de_DE'},
#  {'email': 'aytenjockel@example.net', 'country': 'de_DE'},
#  {'email': 'aytenkade@example.org', 'country': 'de_DE'},
#  {'email': 'azahara61@example.com', 'country': 'es_ES'},
#  {'email': 'azevedolucas@example.org', 'country': 'pt_BR'},
#  {'email': 'azhang@example.com', 'country': 'zh_CN'},
#  {'email': 'azou@example.com', 'country': 'zh_TW'},
#  {'email': 'babatigloria@example.net', 'country': 'it_IT'},
#  {'email': 'baccio06@example.com', 'country': 'it_IT'},
#  {'email': 'baegyeongil@example.com', 'country': 'ko_KR'},
#  {'email': 'baemigyeong@example.com', 'country': 'ko_KR'},
#  {'email': 'baererirene@example.com', 'country': 'de_DE'},
#  {'email': 'bageunjeong@example.net', 'country': 'ko_KR'},
#  {'email': 'bageunseo@example.org', 'country': 'ko_KR'},
#  {'email': 'baggyeongja@example.net', 'country': 'ko_KR'},
#  {'email': 'bagjinu@example.com', 'country': 'ko_KR'},
#  {'email': 'bagyeonghyi@example.org', 'country': 'ko_KR'},
#  {'email': 'baifang@example.org', 'country': 'zh_TW'},
#  {'email': 'baillylucie@example.org', 'country': 'fr_FR'},
#  {'email': 'baldassarescarlatti@example.org', 'country': 'it_IT'},
#  {'email': 'baoki@example.com', 'country': 'ja_JP'},
#  {'email': 'baptistbloch@example.org', 'country': 'de_DE'},
#  {'email': 'barbara27@example.org', 'country': 'pt_BR'},
#  {'email': 'barbara62@example.org', 'country': 'it_IT'},
#  {'email': 'barbierolivier@example.com', 'country': 'fr_FR'},
#  {'email': 'barredamodesta@example.com', 'country': 'es_ES'},
#  {'email': 'barrigaprudencia@example.com', 'country': 'es_ES'},
#  {'email': 'barrosisabella@example.net', 'country': 'pt_BR'},
#  {'email': 'barsantifilippo@example.net', 'country': 'it_IT'},
#  {'email': 'bartlettjohn@example.com', 'country': 'en_US'},
#  {'email': 'bartolome80@example.net', 'country': 'es_ES'},
#  {'email': 'basiliobarba@example.net', 'country': 'es_ES'},
#  {'email': 'bborsellino@example.net', 'country': 'it_IT'},
#  {'email': 'bbousquet@example.net', 'country': 'fr_FR'},
#  {'email': 'bcanals@example.com', 'country': 'es_ES'},
#  {'email': 'bcao@example.com', 'country': 'zh_CN'},
#  {'email': 'bcarriera@example.com', 'country': 'it_IT'},
#  {'email': 'bcastro@example.org', 'country': 'pt_BR'},
#  {'email': 'bchauvin@example.com', 'country': 'fr_FR'},
#  {'email': 'bcornejo@example.net', 'country': 'es_ES'},
#  {'email': 'bduan@example.com', 'country': 'zh_TW'},
#  {'email': 'beate56@example.org', 'country': 'de_DE'},
#  {'email': 'beatrice30@example.org', 'country': 'de_DE'},
#  {'email': 'beatrice50@example.org', 'country': 'it_IT'},
#  {'email': 'begonavera@example.net', 'country': 'es_ES'},
#  {'email': 'beieralan@example.com', 'country': 'de_DE'},
#  {'email': 'beljakovatatjana@example.org', 'country': 'ru_RU'},
#  {'email': 'beljakovpetr@example.org', 'country': 'ru_RU'},
#  {'email': 'bellcheryl@example.org', 'country': 'en_US'},
#  {'email': 'benardtristan@example.com', 'country': 'fr_FR'},
#  {'email': 'benedettofittipaldi@example.com', 'country': 'it_IT'},
#  {'email': 'benitoscalfaro@example.net', 'country': 'it_IT'},
#  {'email': 'benjamin42@example.com', 'country': 'pt_BR'},
#  {'email': 'benthinherrmann@example.com', 'country': 'de_DE'},
#  {'email': 'benvenutobragadin@example.net', 'country': 'it_IT'},
#  {'email': 'benvenutocuda@example.org', 'country': 'it_IT'},
#  {'email': 'benvenutotaliercio@example.com', 'country': 'it_IT'},
#  {'email': 'bernabe68@example.net', 'country': 'es_ES'},
#  {'email': 'bernard34@example.org', 'country': 'fr_FR'},
#  {'email': 'bernardo14@example.org', 'country': 'pt_BR'},
#  {'email': 'bernardocabo@example.org', 'country': 'es_ES'},
#  {'email': 'berta74@example.com', 'country': 'es_ES'},
#  {'email': 'bertinmargot@example.org', 'country': 'fr_FR'},
#  {'email': 'bertrandluc@example.com', 'country': 'fr_FR'},
#  {'email': 'bettysteckel@example.net', 'country': 'de_DE'},
#  {'email': 'bfoscari@example.com', 'country': 'it_IT'},
#  {'email': 'bhayashi@example.org', 'country': 'ja_JP'},
#  {'email': 'biancanogueira@example.org', 'country': 'pt_BR'},
#  {'email': 'biancaortiz@example.org', 'country': 'en_US'},
#  {'email': 'biannelli@example.com', 'country': 'it_IT'},
#  {'email': 'birjukovkondrat@example.net', 'country': 'ru_RU'},
#  {'email': 'bkrein@example.com', 'country': 'de_DE'},
#  {'email': 'blackmark@example.com', 'country': 'en_US'},
#  {'email': 'blanchardaudrey@example.net', 'country': 'fr_FR'},
#  {'email': 'blanchetvirginie@example.org', 'country': 'fr_FR'},
#  {'email': 'blinmonique@example.org', 'country': 'fr_FR'},
#  {'email': 'blinovostap@example.com', 'country': 'ru_RU'},
#  {'email': 'bllabres@example.org', 'country': 'es_ES'},
#  {'email': 'blochgerolf@example.com', 'country': 'de_DE'},
#  {'email': 'blochmargita@example.org', 'country': 'de_DE'},
#  {'email': 'blondelstephanie@example.org', 'country': 'fr_FR'},
#  {'email': 'bloteugene@example.net', 'country': 'fr_FR'},
#  {'email': 'bmartel@example.net', 'country': 'fr_FR'},
#  {'email': 'bmiddleton@example.org', 'country': 'en_US'},
#  {'email': 'bmonteiro@example.org', 'country': 'pt_BR'},
#  {'email': 'bnakajima@example.com', 'country': 'ja_JP'},
#  {'email': 'boaganico@example.org', 'country': 'it_IT'},
#  {'email': 'boiardogiorgio@example.com', 'country': 'it_IT'},
#  {'email': 'bojansamolov@example.org', 'country': 'ru_RU'},
#  {'email': 'boram09@example.net', 'country': 'ko_KR'},
#  {'email': 'borisovvitali@example.net', 'country': 'ru_RU'},
#  {'email': 'bosurgirenata@example.net', 'country': 'it_IT'},
#  {'email': 'boulangerjosephine@example.org', 'country': 'fr_FR'},
#  {'email': 'bourdonanastasie@example.com', 'country': 'fr_FR'},
#  {'email': 'boyeranais@example.org', 'country': 'fr_FR'},
#  {'email': 'bqian@example.org', 'country': 'zh_CN'},
#  {'email': 'branciforteazeglio@example.org', 'country': 'it_IT'},
#  {'email': 'brenda85@example.net', 'country': 'pt_BR'},
#  {'email': 'breno12@example.net', 'country': 'pt_BR'},
#  {'email': 'brian52@example.org', 'country': 'en_US'},
#  {'email': 'brionescrescencia@example.net', 'country': 'es_ES'},
#  {'email': 'brionesjose-antonio@example.com', 'country': 'es_ES'},
#  {'email': 'britroehricht@example.com', 'country': 'de_DE'},
#  {'email': 'brittanyfrank@example.net', 'country': 'en_US'},
#  {'email': 'brownkatie@example.net', 'country': 'en_US'},
#  {'email': 'brugregorio@example.org', 'country': 'es_ES'},
#  {'email': 'bruna02@example.net', 'country': 'pt_BR'},
#  {'email': 'brunilda80@example.net', 'country': 'es_ES'},
#  {'email': 'bryan67@example.net', 'country': 'pt_BR'},
#  {'email': 'bryantjennifer@example.net', 'country': 'en_US'},
#  {'email': 'bsales@example.net', 'country': 'pt_BR'},
#  {'email': 'bsantorio@example.net', 'country': 'it_IT'},
#  {'email': 'bsasaki@example.net', 'country': 'ja_JP'},
#  {'email': 'bseifert@example.org', 'country': 'de_DE'},
#  {'email': 'bseip@example.net', 'country': 'de_DE'},
#  {'email': 'btome@example.net', 'country': 'es_ES'},
#  {'email': 'buenoesteban@example.net', 'country': 'es_ES'},
#  {'email': 'buissonemilie@example.org', 'country': 'fr_FR'},
#  {'email': 'buria@example.com', 'country': 'es_ES'},
#  {'email': 'burkardmueller@example.com', 'country': 'de_DE'},
#  {'email': 'burkhardtkohl@example.net', 'country': 'de_DE'},
#  {'email': 'buttebaldur@example.org', 'country': 'de_DE'},
#  {'email': 'buttecornelius@example.net', 'country': 'de_DE'},
#  {'email': 'bwang@example.net', 'country': 'zh_TW'},
#  {'email': 'bxie@example.net', 'country': 'zh_TW'},
#  {'email': 'bzhu@example.org', 'country': 'zh_TW'},
#  {'email': 'caeweon18@example.com', 'country': 'ko_KR'},
#  {'email': 'caeweon55@example.com', 'country': 'ko_KR'},
#  {'email': 'cafarchiaalessandro@example.com', 'country': 'it_IT'},
#  {'email': 'cafarchiaottavio@example.com', 'country': 'it_IT'},
#  {'email': 'caimin@example.net', 'country': 'zh_TW'},
#  {'email': 'calbocarolina@example.com', 'country': 'it_IT'},
#  {'email': 'calchus@example.net', 'country': 'es_ES'},
#  {'email': 'camila12@example.com', 'country': 'pt_BR'},
#  {'email': 'camposleandro@example.net', 'country': 'pt_BR'},
#  {'email': 'camuccinipaloma@example.org', 'country': 'it_IT'},
#  {'email': 'candidaalcantara@example.org', 'country': 'es_ES'},
#  {'email': 'caoli@example.com', 'country': 'zh_TW'},
#  {'email': 'caoping@example.org', 'country': 'zh_TW'},
#  {'email': 'cardosoana-julia@example.org', 'country': 'pt_BR'},
#  {'email': 'cardosomaria-fernanda@example.org', 'country': 'pt_BR'},
#  {'email': 'cardosonatalia@example.org', 'country': 'pt_BR'},
#  {'email': 'carlo05@example.org', 'country': 'de_DE'},
#  {'email': 'carmelasierra@example.com', 'country': 'es_ES'},
#  {'email': 'carmeloscarponi@example.com', 'country': 'it_IT'},
#  {'email': 'carolina27@example.org', 'country': 'it_IT'},
#  {'email': 'carolina90@example.com', 'country': 'pt_BR'},
#  {'email': 'carolinacarrasco@example.org', 'country': 'es_ES'},
#  {'email': 'carolinacarvalho@example.com', 'country': 'pt_BR'},
#  {'email': 'carolinadoering@example.net', 'country': 'de_DE'},
#  {'email': 'caroline00@example.com', 'country': 'fr_FR'},
#  {'email': 'carolyn83@example.com', 'country': 'en_US'},
#  {'email': 'carstenmina@example.org', 'country': 'de_DE'},
#  {'email': 'carvalhomirella@example.com', 'country': 'pt_BR'},
#  {'email': 'casarinisabella@example.net', 'country': 'it_IT'},
#  {'email': 'casinipaloma@example.net', 'country': 'it_IT'},
#  {'email': 'cassaradaria@example.net', 'country': 'it_IT'},
#  {'email': 'castrodiana@example.com', 'country': 'en_US'},
#  {'email': 'catherinejean@example.org', 'country': 'fr_FR'},
#  {'email': 'cauadias@example.org', 'country': 'pt_BR'},
#  {'email': 'caubry@example.com', 'country': 'fr_FR'},
#  {'email': 'cavalcantilucca@example.net', 'country': 'pt_BR'},
#  {'email': 'cavalcantimaria-cecilia@example.com', 'country': 'pt_BR'},
#  {'email': 'cavalcantipedro-henrique@example.com', 'country': 'pt_BR'},
#  {'email': 'cbeyer@example.net', 'country': 'de_DE'},
#  {'email': 'cchauveau@example.org', 'country': 'fr_FR'},
#  {'email': 'ccheng@example.com', 'country': 'zh_TW'},
#  {'email': 'cding@example.net', 'country': 'zh_CN'},
#  {'email': 'cecilia50@example.com', 'country': 'pt_BR'},
#  {'email': 'ceciliapinto@example.org', 'country': 'pt_BR'},
#  {'email': 'celinebarbier@example.org', 'country': 'fr_FR'},
#  {'email': 'celinechretien@example.net', 'country': 'fr_FR'},
#  {'email': 'cerezoluis@example.net', 'country': 'es_ES'},
#  {'email': 'cfeng@example.net', 'country': 'zh_CN'},
#  {'email': 'cgianinazzi@example.org', 'country': 'it_IT'},
#  {'email': 'cgo@example.net', 'country': 'ko_KR'},
#  {'email': 'cgoto@example.com', 'country': 'ja_JP'},
#  {'email': 'changtao@example.net', 'country': 'zh_CN'},
#  {'email': 'changwei@example.net', 'country': 'zh_CN'},
#  {'email': 'changxiuying@example.org', 'country': 'zh_TW'},
#  {'email': 'changyang@example.net', 'country': 'zh_TW'},
#  {'email': 'chao22@example.net', 'country': 'zh_CN'},
#  {'email': 'chao67@example.org', 'country': 'zh_CN'},
#  {'email': 'chao73@example.org', 'country': 'zh_TW'},
#  {'email': 'chao75@example.com', 'country': 'zh_TW'},
#  {'email': 'chao87@example.org', 'country': 'zh_CN'},
#  {'email': 'chao92@example.com', 'country': 'zh_TW'},
#  {'email': 'chaofang@example.net', 'country': 'zh_TW'},
#  {'email': 'chaohuang@example.org', 'country': 'zh_TW'},
#  {'email': 'chaoluo@example.net', 'country': 'zh_CN'},
#  {'email': 'chaomo@example.org', 'country': 'zh_TW'},
#  {'email': 'chaoyao@example.org', 'country': 'zh_CN'},
#  {'email': 'charo34@example.org', 'country': 'es_ES'},
#  {'email': 'charo74@example.net', 'country': 'es_ES'},
#  {'email': 'chauvetaudrey@example.com', 'country': 'fr_FR'},
#  {'email': 'chemur@example.net', 'country': 'es_ES'},
#  {'email': 'chenglei@example.net', 'country': 'zh_TW'},
#  {'email': 'chenjing@example.net', 'country': 'zh_CN'},
#  {'email': 'cheryl01@example.org', 'country': 'en_US'},
#  {'email': 'chitacalzada@example.com', 'country': 'es_ES'},
#  {'email': 'chiyo31@example.com', 'country': 'ja_JP'},
#  {'email': 'chiyo83@example.com', 'country': 'ja_JP'},
#  {'email': 'christiane73@example.org', 'country': 'fr_FR'},
#  {'email': 'christinadavis@example.com', 'country': 'en_US'},
#  {'email': 'christine52@example.net', 'country': 'fr_FR'},
#  {'email': 'christopher58@example.net', 'country': 'en_US'},
#  {'email': 'chucho53@example.org', 'country': 'es_ES'},
#  {'email': 'ciampigirolamo@example.com', 'country': 'it_IT'},
#  {'email': 'cillihenk@example.org', 'country': 'de_DE'},
#  {'email': 'cindy44@example.org', 'country': 'en_US'},
#  {'email': 'cindysullivan@example.net', 'country': 'en_US'},
#  {'email': 'cinoue@example.org', 'country': 'ja_JP'},
#  {'email': 'cintiazamorano@example.com', 'country': 'es_ES'},
#  {'email': 'ciromunoz@example.net', 'country': 'es_ES'},
#  {'email': 'cisnerosvictor@example.net', 'country': 'en_US'},
#  {'email': 'ckato@example.com', 'country': 'ja_JP'},
#  {'email': 'ckazakov@example.com', 'country': 'ru_RU'},
#  {'email': 'ckong@example.com', 'country': 'zh_TW'},
#  {'email': 'ckozlova@example.com', 'country': 'ru_RU'},
#  {'email': 'claudemallet@example.net', 'country': 'fr_FR'},
#  {'email': 'claudine02@example.org', 'country': 'fr_FR'},
#  {'email': 'claudiokostolzin@example.net', 'country': 'de_DE'},
#  {'email': 'claus-dieter45@example.org', 'country': 'de_DE'},
#  {'email': 'claus-peter05@example.com', 'country': 'de_DE'},
#  {'email': 'clayton98@example.com', 'country': 'en_US'},
#  {'email': 'claytonsheila@example.com', 'country': 'en_US'},
#  {'email': 'clemence83@example.org', 'country': 'fr_FR'},
#  {'email': 'clemens87@example.com', 'country': 'de_DE'},
#  {'email': 'clementchristophe@example.com', 'country': 'fr_FR'},
#  {'email': 'clercpaulette@example.org', 'country': 'fr_FR'},
#  {'email': 'clima@example.org', 'country': 'pt_BR'},
#  {'email': 'climacoribas@example.net', 'country': 'es_ES'},
#  {'email': 'cmiura@example.com', 'country': 'ja_JP'},
#  {'email': 'cmoreira@example.com', 'country': 'pt_BR'},
#  {'email': 'coehaeun@example.com', 'country': 'ko_KR'},
#  {'email': 'coeseonghyeon@example.net', 'country': 'ko_KR'},
#  {'email': 'coeyeji@example.net', 'country': 'ko_KR'},
#  {'email': 'colemancarol@example.net', 'country': 'en_US'},
#  {'email': 'collamor@example.com', 'country': 'es_ES'},
#  {'email': 'concepcion71@example.com', 'country': 'es_ES'},
#  {'email': 'concepcionarmengol@example.com', 'country': 'es_ES'},
#  {'email': 'concepcionroman@example.net', 'country': 'es_ES'},
#  {'email': 'conchasole@example.org', 'country': 'es_ES'},
#  {'email': 'conchavillaverde@example.org', 'country': 'es_ES'},
#  {'email': 'conesaseve@example.com', 'country': 'es_ES'},
#  {'email': 'conleyalexis@example.net', 'country': 'en_US'},
#  {'email': 'connybecker@example.com', 'country': 'de_DE'},
#  {'email': 'corbocoriolano@example.net', 'country': 'it_IT'},
#  {'email': 'corneliocarreno@example.org', 'country': 'es_ES'},
#  {'email': 'correiadaniela@example.com', 'country': 'pt_BR'},
#  {'email': 'cortesefulvio@example.org', 'country': 'it_IT'},
#  {'email': 'couturierdorothee@example.org', 'country': 'fr_FR'},
#  {'email': 'craig30@example.com', 'country': 'en_US'},
#  {'email': 'creising@example.net', 'country': 'de_DE'},
#  {'email': 'crespieufemia@example.com', 'country': 'es_ES'},
#  {'email': 'crespopacifica@example.net', 'country': 'es_ES'},
#  {'email': 'cruzainoa@example.org', 'country': 'es_ES'},
#  {'email': 'crystal68@example.net', 'country': 'en_US'},
#  {'email': 'csato@example.com', 'country': 'ja_JP'},
#  {'email': 'cschneider@example.net', 'country': 'fr_FR'},
#  {'email': 'cschulz@example.com', 'country': 'de_DE'},
#  {'email': 'cseo@example.org', 'country': 'ko_KR'},
#  {'email': 'cuetoeliseo@example.org', 'country': 'es_ES'},
#  {'email': 'cuiguiying@example.net', 'country': 'zh_CN'},
#  {'email': 'cunhacarolina@example.com', 'country': 'pt_BR'},
#  {'email': 'cunhavalentina@example.net', 'country': 'pt_BR'},
#  {'email': 'cunja26@example.com', 'country': 'ko_KR'},
#  {'email': 'cunjabag@example.net', 'country': 'ko_KR'},
#  {'email': 'currovizcaino@example.net', 'country': 'es_ES'},
#  {'email': 'cwilliams@example.org', 'country': 'en_US'},
#  {'email': 'cxiong@example.com', 'country': 'zh_TW'},
#  {'email': 'cyamaguchi@example.net', 'country': 'ja_JP'},
#  {'email': 'czirme@example.org', 'country': 'de_DE'},
#  {'email': 'da-conceicaobruna@example.net', 'country': 'pt_BR'},
#  {'email': 'da-conceicaoleticia@example.org', 'country': 'pt_BR'},
#  {'email': 'da-costajulia@example.com', 'country': 'pt_BR'},
#  {'email': 'da-costanathan@example.org', 'country': 'pt_BR'},
#  {'email': 'da-luzsophia@example.com', 'country': 'pt_BR'},
#  {'email': 'da-motasophia@example.com', 'country': 'pt_BR'},
#  {'email': 'da-rochadaniel@example.org', 'country': 'pt_BR'},
#  {'email': 'da-rosacaio@example.net', 'country': 'pt_BR'},
#  {'email': 'da-rosacatarina@example.com', 'country': 'pt_BR'},
#  {'email': 'da-rosanatalia@example.org', 'country': 'pt_BR'},
#  {'email': 'daifang@example.com', 'country': 'zh_TW'},
#  {'email': 'daiguiying@example.com', 'country': 'zh_CN'},
#  {'email': 'daiming@example.org', 'country': 'zh_CN'},
#  {'email': 'daiyang@example.com', 'country': 'zh_TW'},
#  {'email': 'daltonnicole@example.com', 'country': 'en_US'},
#  {'email': 'dan24@example.net', 'country': 'es_ES'},
#  {'email': 'dan91@example.net', 'country': 'de_DE'},
#  {'email': 'dandres@example.org', 'country': 'es_ES'},
#  {'email': 'daniel24@example.net', 'country': 'fr_FR'},
#  {'email': 'daniela66@example.com', 'country': 'pt_BR'},
#  {'email': 'danielleherrera@example.net', 'country': 'en_US'},
#  {'email': 'danielrezende@example.com', 'country': 'pt_BR'},
#  {'email': 'danilo66@example.net', 'country': 'pt_BR'},
#  {'email': 'danilovasinklitikija@example.org', 'country': 'ru_RU'},
#  {'email': 'danilovfeofan@example.net', 'country': 'ru_RU'},
#  {'email': 'dariacremonesi@example.org', 'country': 'it_IT'},
#  {'email': 'darroyo@example.com', 'country': 'es_ES'},
#  {'email': 'david52@example.net', 'country': 'de_DE'},
#  {'email': 'david87@example.org', 'country': 'fr_FR'},
#  {'email': 'davidchevallier@example.org', 'country': 'fr_FR'},
#  {'email': 'davidgarcia@example.net', 'country': 'en_US'},
#  {'email': 'davidovauljana@example.com', 'country': 'ru_RU'},
#  {'email': 'davisalyssa@example.org', 'country': 'en_US'},
#  {'email': 'dawnboyle@example.com', 'country': 'en_US'},
#  {'email': 'dawsonnicole@example.com', 'country': 'en_US'},
#  {'email': 'dazavalentin@example.net', 'country': 'es_ES'},
#  {'email': 'dbajamonti@example.org', 'country': 'it_IT'},
#  {'email': 'dbarbero@example.org', 'country': 'es_ES'},
#  {'email': 'dbarrios@example.org', 'country': 'es_ES'},
#  {'email': 'dbonatti@example.net', 'country': 'it_IT'},
#  {'email': 'dbusquets@example.com', 'country': 'es_ES'},
#  {'email': 'dcarvalho@example.com', 'country': 'pt_BR'},
#  {'email': 'dchang@example.net', 'country': 'zh_TW'},
#  {'email': 'dchen@example.com', 'country': 'zh_CN'},
#  {'email': 'dcostela@example.org', 'country': 'pt_BR'},
#  {'email': 'ddaza@example.org', 'country': 'es_ES'},
#  {'email': 'dde-oliveira@example.com', 'country': 'fr_FR'},
#  {'email': 'ddiego@example.org', 'country': 'es_ES'},
#  {'email': 'ddoering@example.com', 'country': 'de_DE'},
#  {'email': 'debra16@example.net', 'country': 'en_US'},
#  {'email': 'debra90@example.net', 'country': 'en_US'},
#  {'email': 'delahayehenriette@example.org', 'country': 'fr_FR'},
#  {'email': 'delfino47@example.net', 'country': 'it_IT'},
#  {'email': 'deliazaenker@example.org', 'country': 'de_DE'},
#  {'email': 'dementevaevpraksija@example.com', 'country': 'ru_RU'},
#  {'email': 'dementevdemjan@example.net', 'country': 'ru_RU'},
#  {'email': 'demid1972@example.com', 'country': 'ru_RU'},
#  {'email': 'dengtao@example.org', 'country': 'zh_TW'},
#  {'email': 'denise04@example.org', 'country': 'fr_FR'},
#  {'email': 'denisechan@example.com', 'country': 'en_US'},
#  {'email': 'descampspaul@example.net', 'country': 'fr_FR'},
#  {'email': 'detlev23@example.org', 'country': 'de_DE'},
#  {'email': 'dgibert@example.org', 'country': 'es_ES'},
#  {'email': 'dgim@example.com', 'country': 'ko_KR'},
#  {'email': 'dhamel@example.com', 'country': 'fr_FR'},
#  {'email': 'dianaortese@example.org', 'country': 'it_IT'},
#  {'email': 'dianawilkerson@example.org', 'country': 'en_US'},
#  {'email': 'diazkimberly@example.com', 'country': 'en_US'},
#  {'email': 'diego75@example.org', 'country': 'pt_BR'},
#  {'email': 'dietmar35@example.org', 'country': 'de_DE'},
#  {'email': 'dietrich47@example.com', 'country': 'de_DE'},
#  {'email': 'dimas11@example.org', 'country': 'es_ES'},
#  {'email': 'dina76@example.net', 'country': 'it_IT'},
#  {'email': 'dinasgarbi@example.org', 'country': 'it_IT'},
#  {'email': 'dinggang@example.net', 'country': 'zh_TW'},
#  {'email': 'dingguiying@example.org', 'country': 'zh_CN'},
#  {'email': 'djiang@example.net', 'country': 'zh_TW'},
#  {'email': 'djohnson@example.net', 'country': 'en_US'},
#  {'email': 'dkang@example.net', 'country': 'zh_CN'},
#  {'email': 'dkhan@example.net', 'country': 'en_US'},
#  {'email': 'dlabbe@example.org', 'country': 'fr_FR'},
#  {'email': 'dli@example.com', 'country': 'zh_TW'},
#  {'email': 'dliao@example.org', 'country': 'zh_TW'},
#  {'email': 'dmatsumoto@example.com', 'country': 'ja_JP'},
#  {'email': 'dmitri_1993@example.net', 'country': 'ru_RU'},
#  {'email': 'dmosquera@example.net', 'country': 'es_ES'},
#  {'email': 'dmunoz@example.com', 'country': 'fr_FR'},
#  {'email': 'dmurialdo@example.org', 'country': 'it_IT'},
#  {'email': 'dobromisl_92@example.net', 'country': 'ru_RU'},
#  {'email': 'doerschnerreimer@example.net', 'country': 'de_DE'},
#  {'email': 'dohyeono@example.com', 'country': 'ko_KR'},
#  {'email': 'dominiquereynaud@example.com', 'country': 'fr_FR'},
#  {'email': 'domitila21@example.net', 'country': 'es_ES'},
#  {'email': 'donarellipiero@example.org', 'country': 'it_IT'},
#  {'email': 'donarodolfo@example.com', 'country': 'it_IT'},
#  {'email': 'donato81@example.com', 'country': 'es_ES'},
#  {'email': 'donghyeon17@example.net', 'country': 'ko_KR'},
#  {'email': 'donghyeon54@example.net', 'country': 'ko_KR'},
#  {'email': 'donghyeongim@example.com', 'country': 'ko_KR'},
#  {'email': 'dongjun@example.org', 'country': 'zh_CN'},
#  {'email': 'dongxiulan@example.com', 'country': 'zh_CN'},
#  {'email': 'donnaevans@example.com', 'country': 'en_US'},
#  {'email': 'dorofeevsamson@example.com', 'country': 'ru_RU'},
#  {'email': 'dorotheeblanchet@example.com', 'country': 'fr_FR'},
#  {'email': 'douglassmith@example.org', 'country': 'en_US'},
#  {'email': 'doyun72@example.org', 'country': 'ko_KR'},
#  {'email': 'doyunbag@example.net', 'country': 'ko_KR'},
#  {'email': 'dpereira@example.com', 'country': 'pt_BR'},
#  {'email': 'dpineau@example.org', 'country': 'fr_FR'},
#  {'email': 'dqiu@example.net', 'country': 'zh_CN'},
#  {'email': 'dselezneva@example.org', 'country': 'ru_RU'},
#  {'email': 'duartegustavo-henrique@example.net', 'country': 'pt_BR'},
#  {'email': 'duarteyuri@example.org', 'country': 'pt_BR'},
#  {'email': 'duprediane@example.com', 'country': 'fr_FR'},
#  {'email': 'durante62@example.org', 'country': 'it_IT'},
#  {'email': 'dwang@example.net', 'country': 'zh_TW'},
#  {'email': 'dwu@example.org', 'country': 'zh_CN'},
#  {'email': 'dxiao@example.org', 'country': 'zh_TW'},
#  {'email': 'dxiong@example.org', 'country': 'zh_CN'},
#  {'email': 'dyamaguchi@example.com', 'country': 'ja_JP'},
#  {'email': 'dyin@example.net', 'country': 'zh_CN'},
#  {'email': 'dyoshida@example.org', 'country': 'ja_JP'},
#  {'email': 'dzeng@example.net', 'country': 'zh_TW'},
#  {'email': 'ecarvalho@example.org', 'country': 'pt_BR'},
#  {'email': 'eckartfliegner@example.com', 'country': 'de_DE'},
#  {'email': 'edithbousquet@example.org', 'country': 'fr_FR'},
#  {'email': 'edumont@example.net', 'country': 'fr_FR'},
#  {'email': 'edward34@example.com', 'country': 'en_US'},
#  {'email': 'edwinstolze@example.net', 'country': 'de_DE'},
#  {'email': 'eferrara@example.net', 'country': 'it_IT'},
#  {'email': 'efimovporfiri@example.net', 'country': 'ru_RU'},
#  {'email': 'efrainpuerta@example.com', 'country': 'es_ES'},
#  {'email': 'egibilisco@example.com', 'country': 'it_IT'},
#  {'email': 'egim@example.com', 'country': 'ko_KR'},
#  {'email': 'egim@example.net', 'country': 'ko_KR'},
#  {'email': 'egranados@example.org', 'country': 'es_ES'},
#  {'email': 'ehe@example.net', 'country': 'zh_CN'},
#  {'email': 'ei@example.org', 'country': 'ko_KR'},
#  {'email': 'eileen77@example.com', 'country': 'de_DE'},
#  {'email': 'ekkehartullmann@example.net', 'country': 'de_DE'},
#  {'email': 'ekong@example.org', 'country': 'zh_CN'},
#  {'email': 'ekrebs@example.net', 'country': 'de_DE'},
#  {'email': 'eladeck@example.com', 'country': 'de_DE'},
#  {'email': 'eleanora16@example.org', 'country': 'it_IT'},
#  {'email': 'eli@example.com', 'country': 'zh_TW'},
#  {'email': 'eliaschelo@example.net', 'country': 'es_ES'},
#  {'email': 'eliasyessica@example.com', 'country': 'es_ES'},
#  {'email': 'elisa48@example.org', 'country': 'es_ES'},
#  {'email': 'elisabethbousquet@example.net', 'country': 'fr_FR'},
#  {'email': 'elisetexier@example.org', 'country': 'fr_FR'},
#  {'email': 'elizabeth98@example.org', 'country': 'en_US'},
#  {'email': 'elizabeth99@example.net', 'country': 'en_US'},
#  {'email': 'elizabethenglish@example.net', 'country': 'en_US'},
#  {'email': 'elizabethhurley@example.org', 'country': 'en_US'},
#  {'email': 'elizarsamolov@example.com', 'country': 'ru_RU'},
#  {'email': 'elizaveta16@example.net', 'country': 'ru_RU'},
#  {'email': 'ellopis@example.net', 'country': 'es_ES'},
#  {'email': 'elmarweiss@example.com', 'country': 'de_DE'},
#  {'email': 'eloisa35@example.com', 'country': 'es_ES'},
#  {'email': 'elvira47@example.com', 'country': 'it_IT'},
#  {'email': 'elviraseifert@example.org', 'country': 'de_DE'},
#  {'email': 'emanuella17@example.net', 'country': 'pt_BR'},
#  {'email': 'emanuella63@example.com', 'country': 'pt_BR'},
#  {'email': 'emanuellycardoso@example.com', 'country': 'pt_BR'},
#  {'email': 'emanuellysales@example.com', 'country': 'pt_BR'},
#  {'email': 'emarion@example.com', 'country': 'fr_FR'},
#  {'email': 'emary@example.com', 'country': 'fr_FR'},
#  {'email': 'emedina@example.com', 'country': 'en_US'},
#  {'email': 'emilejoubert@example.net', 'country': 'fr_FR'},
#  {'email': 'emilio62@example.com', 'country': 'it_IT'},
#  {'email': 'emily58@example.org', 'country': 'en_US'},
#  {'email': 'emilylara@example.org', 'country': 'en_US'},
#  {'email': 'emilymason@example.com', 'country': 'en_US'},
#  {'email': 'emma74@example.net', 'country': 'it_IT'},
#  {'email': 'emorvan@example.com', 'country': 'fr_FR'},
#  {'email': 'endohideki@example.com', 'country': 'ja_JP'},
#  {'email': 'enogueira@example.com', 'country': 'pt_BR'},
#  {'email': 'enorman@example.net', 'country': 'en_US'},
#  {'email': 'enrico07@example.org', 'country': 'it_IT'},
#  {'email': 'enricoda-luz@example.com', 'country': 'pt_BR'},
#  {'email': 'enzo-gabriel15@example.net', 'country': 'pt_BR'},
#  {'email': 'enzo23@example.com', 'country': 'it_IT'},
#  {'email': 'enzo30@example.net', 'country': 'pt_BR'},
#  {'email': 'epifanevdokimov@example.org', 'country': 'ru_RU'},
#  {'email': 'epozo@example.org', 'country': 'es_ES'},
#  {'email': 'eraldo24@example.net', 'country': 'it_IT'},
#  {'email': 'ercanniemeier@example.net', 'country': 'de_DE'},
#  {'email': 'eric00@example.com', 'country': 'en_US'},
#  {'email': 'eric27@example.com', 'country': 'en_US'},
#  {'email': 'eric48@example.com', 'country': 'en_US'},
#  {'email': 'ericbenavides@example.com', 'country': 'es_ES'},
#  {'email': 'erika20@example.net', 'country': 'it_IT'},
#  {'email': 'erika80@example.com', 'country': 'en_US'},
#  {'email': 'erikaferretti@example.com', 'country': 'it_IT'},
#  {'email': 'ermannovercelloni@example.com', 'country': 'it_IT'},
#  {'email': 'ermenegildoburcardo@example.org', 'country': 'it_IT'},
#  {'email': 'ermesgarobbio@example.com', 'country': 'it_IT'},
#  {'email': 'erofe1984@example.net', 'country': 'ru_RU'},
#  {'email': 'eryu@example.org', 'country': 'ko_KR'},
#  {'email': 'escamillamartina@example.com', 'country': 'es_ES'},
#  {'email': 'eseip@example.com', 'country': 'de_DE'},
#  {'email': 'esmeraldacanton@example.com', 'country': 'es_ES'},
#  {'email': 'esmeraldarosales@example.com', 'country': 'es_ES'},
#  {'email': 'esoelzer@example.net', 'country': 'de_DE'},
#  {'email': 'esterhettner@example.com', 'country': 'de_DE'},
#  {'email': 'estherrossello@example.net', 'country': 'es_ES'},
#  {'email': 'ethan63@example.net', 'country': 'en_US'},
#  {'email': 'ethomas@example.org', 'country': 'en_US'},
#  {'email': 'etienne13@example.com', 'country': 'fr_FR'},
#  {'email': 'etienne48@example.org', 'country': 'fr_FR'},
#  {'email': 'etiennedenis@example.org', 'country': 'fr_FR'},
#  {'email': 'etiennelegrand@example.com', 'country': 'fr_FR'},
#  {'email': 'ettavezzali@example.org', 'country': 'it_IT'},
#  {'email': 'etzleringrid@example.org', 'country': 'de_DE'},
#  {'email': 'eugene26@example.com', 'country': 'fr_FR'},
#  {'email': 'eugeniazoppetti@example.org', 'country': 'it_IT'},
#  {'email': 'eulaliapedraza@example.net', 'country': 'es_ES'},
#  {'email': 'eungyeonggang@example.org', 'country': 'ko_KR'},
#  {'email': 'eunjeongryu@example.net', 'country': 'ko_KR'},
#  {'email': 'eunji03@example.net', 'country': 'ko_KR'},
#  {'email': 'eunji22@example.net', 'country': 'ko_KR'},
#  {'email': 'eunjigim@example.com', 'country': 'ko_KR'},
#  {'email': 'eunju10@example.net', 'country': 'ko_KR'},
#  {'email': 'eunju15@example.net', 'country': 'ko_KR'},
#  {'email': 'eunju68@example.org', 'country': 'ko_KR'},
#  {'email': 'eunseo63@example.net', 'country': 'ko_KR'},
#  {'email': 'eunseo69@example.org', 'country': 'ko_KR'},
#  {'email': 'eunyeonggang@example.com', 'country': 'ko_KR'},
#  {'email': 'eunyeongyun@example.org', 'country': 'ko_KR'},
#  {'email': 'eusebiasanjuan@example.org', 'country': 'es_ES'},
#  {'email': 'eustaquiocaceres@example.net', 'country': 'es_ES'},
#  {'email': 'eutimio19@example.com', 'country': 'es_ES'},
#  {'email': 'eva05@example.net', 'country': 'de_DE'},
#  {'email': 'evansscott@example.com', 'country': 'en_US'},
#  {'email': 'evdokim1979@example.com', 'country': 'ru_RU'},
#  {'email': 'evelinloechel@example.com', 'country': 'de_DE'},
#  {'email': 'evgraf_2009@example.net', 'country': 'ru_RU'},
#  {'email': 'evita78@example.com', 'country': 'es_ES'},
#  {'email': 'ewieloch@example.org', 'country': 'de_DE'},
#  {'email': 'fabia46@example.net', 'country': 'it_IT'},
#  {'email': 'fabiana24@example.org', 'country': 'es_ES'},
#  {'email': 'fabianangel@example.org', 'country': 'es_ES'},
#  {'email': 'fabiodisdero@example.com', 'country': 'it_IT'},
#  {'email': 'faivrevictor@example.org', 'country': 'fr_FR'},
#  {'email': 'fang03@example.net', 'country': 'zh_TW'},
#  {'email': 'fang10@example.org', 'country': 'zh_TW'},
#  {'email': 'fang33@example.org', 'country': 'zh_CN'},
#  {'email': 'fang34@example.com', 'country': 'zh_TW'},
#  {'email': 'fang48@example.org', 'country': 'zh_TW'},
#  {'email': 'fang64@example.net', 'country': 'zh_TW'},
#  {'email': 'fang65@example.com', 'country': 'zh_CN'},
#  {'email': 'fang81@example.com', 'country': 'zh_CN'},
#  {'email': 'fang87@example.net', 'country': 'zh_CN'},
#  {'email': 'fangfan@example.net', 'country': 'zh_TW'},
#  {'email': 'fanggu@example.net', 'country': 'zh_CN'},
#  {'email': 'fanghu@example.org', 'country': 'zh_TW'},
#  {'email': 'fangkang@example.net', 'country': 'zh_TW'},
#  {'email': 'fangmin@example.org', 'country': 'zh_TW'},
#  {'email': 'fangpeng@example.com', 'country': 'zh_TW'},
#  {'email': 'fangqiu@example.net', 'country': 'zh_TW'},
#  {'email': 'fangsun@example.com', 'country': 'zh_TW'},
#  {'email': 'fangtang@example.org', 'country': 'zh_CN'},
#  {'email': 'fangwei@example.org', 'country': 'zh_CN'},
#  {'email': 'fanny48@example.org', 'country': 'de_DE'},
#  {'email': 'fanyong@example.net', 'country': 'zh_TW'},
#  {'email': 'fbaranov@example.net', 'country': 'ru_RU'},
#  {'email': 'fbarnes@example.org', 'country': 'en_US'},
#  {'email': 'fbianchini@example.com', 'country': 'it_IT'},
#  {'email': 'fbruder@example.org', 'country': 'de_DE'},
#  {'email': 'fcarpentier@example.com', 'country': 'fr_FR'},
#  {'email': 'fcassara@example.org', 'country': 'it_IT'},
#  {'email': 'fcosta@example.org', 'country': 'es_ES'},
#  {'email': 'febe30@example.net', 'country': 'es_ES'},
#  {'email': 'federicimarco@example.com', 'country': 'it_IT'},
#  {'email': 'federigobattaglia@example.org', 'country': 'it_IT'},
#  {'email': 'fedoseevizot@example.com', 'country': 'ru_RU'},
#  {'email': 'felicia36@example.org', 'country': 'es_ES'},
#  {'email': 'feliciabirnbaum@example.com', 'country': 'de_DE'},
#  {'email': 'feliciathomas@example.com', 'country': 'en_US'},
#  {'email': 'felicidadtorralba@example.org', 'country': 'es_ES'},
#  {'email': 'feliks2020@example.com', 'country': 'ru_RU'},
#  {'email': 'feliks51@example.net', 'country': 'ru_RU'},
#  {'email': 'fengming@example.net', 'country': 'zh_CN'},
#  {'email': 'fengqiang@example.net', 'country': 'zh_TW'},
#  {'email': 'feofan2005@example.com', 'country': 'ru_RU'},
#  {'email': 'feoktist_33@example.com', 'country': 'ru_RU'},
#  {'email': 'feoktistlavrentev@example.net', 'country': 'ru_RU'},
#  {'email': 'fernandacortese@example.com', 'country': 'it_IT'},
#  {'email': 'fernando05@example.org', 'country': 'pt_BR'},
#  {'email': 'fernando36@example.net', 'country': 'pt_BR'},
#  {'email': 'fernando88@example.net', 'country': 'pt_BR'},
#  {'email': 'fernandoteixeira@example.com', 'country': 'pt_BR'},
#  {'email': 'ferrandezlupita@example.net', 'country': 'es_ES'},
#  {'email': 'ferreiracalebe@example.org', 'country': 'pt_BR'},
#  {'email': 'fgu@example.org', 'country': 'zh_CN'},
#  {'email': 'fhethur@example.com', 'country': 'de_DE'},
#  {'email': 'fhuang@example.com', 'country': 'zh_TW'},
#  {'email': 'fidelapozuelo@example.com', 'country': 'es_ES'},
#  {'email': 'filippellimanuel@example.com', 'country': 'it_IT'},
#  {'email': 'filippo18@example.net', 'country': 'it_IT'},
#  {'email': 'filippovaalevtina@example.com', 'country': 'ru_RU'},
#  {'email': 'finleydonald@example.net', 'country': 'en_US'},
#  {'email': 'finottodonato@example.org', 'country': 'it_IT'},
#  {'email': 'fjo@example.net', 'country': 'ko_KR'},
#  {'email': 'fliang@example.net', 'country': 'zh_TW'},
#  {'email': 'florenciaarellano@example.com', 'country': 'es_ES'},
#  {'email': 'florentin1975@example.net', 'country': 'ru_RU'},
#  {'email': 'florentinkolesnikov@example.org', 'country': 'ru_RU'},
#  {'email': 'floresbrian@example.net', 'country': 'en_US'},
#  {'email': 'floreschristopher@example.com', 'country': 'en_US'},
#  {'email': 'fmarion@example.net', 'country': 'fr_FR'},
#  {'email': 'fmartins@example.com', 'country': 'pt_BR'},
#  {'email': 'fmcmahon@example.net', 'country': 'en_US'},
#  {'email': 'fmedina@example.net', 'country': 'es_ES'},
#  {'email': 'fnakamura@example.net', 'country': 'ja_JP'},
#  {'email': 'fnunes@example.net', 'country': 'pt_BR'},
#  {'email': 'foavittoria@example.com', 'country': 'it_IT'},
#  {'email': 'foersteroda@example.com', 'country': 'de_DE'},
#  {'email': 'foerstersylvana@example.net', 'country': 'de_DE'},
#  {'email': 'fogacalara@example.org', 'country': 'pt_BR'},
#  {'email': 'fokinsamson@example.net', 'country': 'ru_RU'},
#  {'email': 'foma35@example.org', 'country': 'ru_RU'},
#  {'email': 'fomintvorimir@example.net', 'country': 'ru_RU'},
#  {'email': 'fontloreto@example.net', 'country': 'es_ES'},
#  {'email': 'fortunat_91@example.org', 'country': 'ru_RU'},
#  {'email': 'fortunat37@example.org', 'country': 'ru_RU'},
#  {'email': 'fosterstephen@example.net', 'country': 'en_US'},
#  {'email': 'fpan@example.com', 'country': 'zh_TW'},
#  {'email': 'franciscopereira@example.net', 'country': 'pt_BR'},
#  {'email': 'francknoel@example.net', 'country': 'fr_FR'},
#  {'email': 'franco24@example.com', 'country': 'it_IT'},
#  {'email': 'francogiannone@example.org', 'country': 'it_IT'},
#  {'email': 'francoise66@example.com', 'country': 'de_DE'},
#  {'email': 'francojuan-manuel@example.org', 'country': 'es_ES'},
#  {'email': 'francorogner@example.net', 'country': 'de_DE'},
#  {'email': 'frankeelli@example.org', 'country': 'de_DE'},
#  {'email': 'frederickmartin@example.org', 'country': 'en_US'},
#  {'email': 'freitasmaria-julia@example.org', 'country': 'pt_BR'},
#  {'email': 'freudenbergerortrud@example.net', 'country': 'de_DE'},
#  {'email': 'frol_1975@example.net', 'country': 'ru_RU'},
#  {'email': 'fseo@example.net', 'country': 'ko_KR'},
#  {'email': 'fshimizu@example.org', 'country': 'ja_JP'},
#  {'email': 'fsibilia@example.net', 'country': 'it_IT'},
#  {'email': 'fsong@example.com', 'country': 'zh_TW'},
#  {'email': 'fujie@example.net', 'country': 'zh_CN'},
#  {'email': 'fujiikana@example.org', 'country': 'ja_JP'},
#  {'email': 'fujiiyosuke@example.org', 'country': 'ja_JP'},
#  {'email': 'fyoshida@example.net', 'country': 'ja_JP'},
#  {'email': 'gabrielaragao@example.net', 'country': 'pt_BR'},
#  {'email': 'gabriellainnocenti@example.org', 'country': 'it_IT'},
#  {'email': 'gabriellozano@example.com', 'country': 'es_ES'},
#  {'email': 'gabriellyjesus@example.org', 'country': 'pt_BR'},
#  {'email': 'gabrielthomas@example.org', 'country': 'en_US'},
#  {'email': 'gala16@example.org', 'country': 'es_ES'},
#  {'email': 'galassoborsiere@example.com', 'country': 'it_IT'},
#  {'email': 'galassomalacarne@example.org', 'country': 'it_IT'},
#  {'email': 'galileimilo@example.org', 'country': 'it_IT'},
#  {'email': 'galina1998@example.net', 'country': 'ru_RU'},
#  {'email': 'galo38@example.com', 'country': 'es_ES'},
#  {'email': 'galuppivenancio@example.com', 'country': 'it_IT'},
#  {'email': 'gang06@example.net', 'country': 'zh_TW'},
#  {'email': 'gang62@example.com', 'country': 'zh_CN'},
#  {'email': 'gang96@example.net', 'country': 'zh_CN'},
#  {'email': 'ganggu@example.org', 'country': 'zh_TW'},
#  {'email': 'gangjin@example.net', 'country': 'zh_CN'},
#  {'email': 'gangshen@example.net', 'country': 'zh_CN'},
#  {'email': 'gangtang@example.net', 'country': 'zh_TW'},
#  {'email': 'gangxue@example.net', 'country': 'zh_CN'},
#  {'email': 'gangzhou@example.org', 'country': 'zh_CN'},
#  {'email': 'gaoping@example.net', 'country': 'zh_TW'},
#  {'email': 'garciadelfina@example.net', 'country': 'es_ES'},
#  {'email': 'garciajoshua@example.org', 'country': 'en_US'},
#  {'email': 'garozzobenito@example.net', 'country': 'it_IT'},
#  {'email': 'garrettgavin@example.com', 'country': 'en_US'},
#  {'email': 'gavrilovamarfa@example.org', 'country': 'ru_RU'},
#  {'email': 'gbag@example.org', 'country': 'ko_KR'},
#  {'email': 'gbai@example.org', 'country': 'zh_CN'},
#  {'email': 'gbesnard@example.com', 'country': 'fr_FR'},
#  {'email': 'gboix@example.com', 'country': 'es_ES'},
#  {'email': 'gcabanas@example.org', 'country': 'es_ES'},
#  {'email': 'gclement@example.com', 'country': 'fr_FR'},
#  {'email': 'gdevaux@example.net', 'country': 'fr_FR'},
#  {'email': 'gdias@example.net', 'country': 'pt_BR'},
#  {'email': 'gedeon1986@example.org', 'country': 'ru_RU'},
#  {'email': 'geert57@example.com', 'country': 'de_DE'},
#  {'email': 'gehringerknud@example.net', 'country': 'de_DE'},
#  {'email': 'gema55@example.net', 'country': 'es_ES'},
#  {'email': 'gennadi_2018@example.com', 'country': 'ru_RU'},
#  {'email': 'gentryjodi@example.net', 'country': 'en_US'},
#  {'email': 'georgi_1980@example.com', 'country': 'ru_RU'},
#  {'email': 'gerard20@example.net', 'country': 'fr_FR'},
#  {'email': 'gerasim_29@example.org', 'country': 'ru_RU'},
#  {'email': 'gerolf39@example.com', 'country': 'de_DE'},
#  {'email': 'gertrudiscompany@example.com', 'country': 'es_ES'},
#  {'email': 'geschesontag@example.com', 'country': 'de_DE'},
#  {'email': 'gfilogamo@example.net', 'country': 'it_IT'},
#  {'email': 'ggabbana@example.net', 'country': 'it_IT'},
#  {'email': 'ggeisler@example.net', 'country': 'de_DE'},
#  {'email': 'ggomes@example.net', 'country': 'pt_BR'},
#  {'email': 'ggosselin@example.net', 'country': 'fr_FR'},
#  {'email': 'giacobbe82@example.org', 'country': 'it_IT'},
#  {'email': 'giada18@example.com', 'country': 'it_IT'},
#  {'email': 'giadamarsili@example.org', 'country': 'it_IT'},
#  {'email': 'gianlucafilippini@example.org', 'country': 'it_IT'},
#  {'email': 'gierschnerisolde@example.com', 'country': 'de_DE'},
#  {'email': 'giessanni@example.org', 'country': 'de_DE'},
#  {'email': 'gil97@example.org', 'country': 'es_ES'},
#  {'email': 'gilberto50@example.com', 'country': 'it_IT'},
#  {'email': 'gilbertomonaco@example.com', 'country': 'it_IT'},
#  {'email': 'gimcunja@example.org', 'country': 'ko_KR'},
#  {'email': 'gimhaeun@example.org', 'country': 'ko_KR'},
#  {'email': 'gimhyejin@example.org', 'country': 'ko_KR'},
#  {'email': 'gimjeonghun@example.org', 'country': 'ko_KR'},
#  {'email': 'gimjeongja@example.net', 'country': 'ko_KR'},
#  {'email': 'gimjeongnam@example.net', 'country': 'ko_KR'},
#  {'email': 'gimjeongsug@example.org', 'country': 'ko_KR'},
#  {'email': 'gimjimin@example.com', 'country': 'ko_KR'},
#  {'email': 'gimmigyeong@example.com', 'country': 'ko_KR'},
#  {'email': 'gimmijeong@example.org', 'country': 'ko_KR'},
#  {'email': 'gimseongmin@example.net', 'country': 'ko_KR'},
#  {'email': 'gimseongsu@example.com', 'country': 'ko_KR'},
#  {'email': 'gimsumin@example.com', 'country': 'ko_KR'},
#  {'email': 'gimyejun@example.net', 'country': 'ko_KR'},
#  {'email': 'gimyeonghwan@example.com', 'country': 'ko_KR'},
#  {'email': 'gimyeongil@example.net', 'country': 'ko_KR'},
#  {'email': 'gimyeongsig@example.com', 'country': 'ko_KR'},
#  {'email': 'gimyeongsun@example.com', 'country': 'ko_KR'},
#  {'email': 'gimyujin@example.org', 'country': 'ko_KR'},
#  {'email': 'gioacchinopassalacqua@example.net', 'country': 'it_IT'},
#  {'email': 'gioele31@example.com', 'country': 'it_IT'},
#  {'email': 'giovannadelle@example.org', 'country': 'it_IT'},
#  {'email': 'giovannastahr@example.com', 'country': 'de_DE'},
#  {'email': 'giovannipace@example.net', 'country': 'it_IT'},
#  {'email': 'gironascension@example.net', 'country': 'es_ES'},
#  {'email': 'giulianaalighieri@example.net', 'country': 'it_IT'},
#  {'email': 'giuliocarullo@example.net', 'country': 'it_IT'},
#  {'email': 'giuseppeboitani@example.com', 'country': 'it_IT'},
#  {'email': 'giuseppevianello@example.net', 'country': 'it_IT'},
#  {'email': 'gjopich@example.com', 'country': 'de_DE'},
#  {'email': 'glaporte@example.net', 'country': 'fr_FR'},
#  {'email': 'glauco30@example.com', 'country': 'es_ES'},
#  {'email': 'gliang@example.com', 'country': 'zh_TW'},
#  {'email': 'gloria88@example.net', 'country': 'it_IT'},
#  {'email': 'gmartins@example.net', 'country': 'pt_BR'},
#  {'email': 'gmattarella@example.org', 'country': 'it_IT'},
#  {'email': 'gnguyen@example.net', 'country': 'fr_FR'},
#  {'email': 'goffredo52@example.org', 'country': 'it_IT'},
#  {'email': 'gojeonghun@example.com', 'country': 'ko_KR'},
#  {'email': 'goldonilidia@example.com', 'country': 'it_IT'},
#  {'email': 'golubevstanislav@example.net', 'country': 'ru_RU'},
#  {'email': 'gomesbrenda@example.net', 'country': 'pt_BR'},
#  {'email': 'goncalvesemanuelly@example.org', 'country': 'pt_BR'},
#  {'email': 'goncalvesjoao-felipe@example.org', 'country': 'pt_BR'},
#  {'email': 'gongyang@example.net', 'country': 'zh_CN'},
#  {'email': 'gopizzi@example.net', 'country': 'it_IT'},
#  {'email': 'gorlitzrosa-maria@example.com', 'country': 'de_DE'},
#  {'email': 'gortega@example.com', 'country': 'es_ES'},
#  {'email': 'gostomisl_48@example.com', 'country': 'ru_RU'},
#  {'email': 'gostomislsokolov@example.com', 'country': 'ru_RU'},
#  {'email': 'gotthardheinz-dieter@example.org', 'country': 'de_DE'},
#  {'email': 'gparmitano@example.net', 'country': 'it_IT'},
#  {'email': 'grace16@example.com', 'country': 'en_US'},
#  {'email': 'grasisidora@example.org', 'country': 'es_ES'},
#  {'email': 'grauaitana@example.net', 'country': 'es_ES'},
#  {'email': 'grecagiammusso@example.org', 'country': 'it_IT'},
#  {'email': 'greenjohn@example.net', 'country': 'en_US'},
#  {'email': 'gregoirelejeune@example.com', 'country': 'fr_FR'},
#  {'email': 'gregordoerr@example.com', 'country': 'de_DE'},
#  {'email': 'gren@example.org', 'country': 'zh_CN'},
#  {'email': 'gretel03@example.org', 'country': 'de_DE'},
#  {'email': 'gretelholsten@example.com', 'country': 'de_DE'},
#  {'email': 'griselda64@example.net', 'country': 'it_IT'},
#  {'email': 'grishinradim@example.com', 'country': 'ru_RU'},
#  {'email': 'grisonifabrizio@example.net', 'country': 'it_IT'},
#  {'email': 'grittimorena@example.org', 'country': 'it_IT'},
#  {'email': 'grolland@example.org', 'country': 'fr_FR'},
#  {'email': 'gromovizjaslav@example.net', 'country': 'ru_RU'},
#  {'email': 'grose@example.com', 'country': 'de_DE'},
#  {'email': 'grossilicia@example.com', 'country': 'it_IT'},
#  {'email': 'grossini@example.net', 'country': 'it_IT'},
#  {'email': 'grosssteven@example.com', 'country': 'en_US'},
#  {'email': 'gschomber@example.org', 'country': 'de_DE'},
#  {'email': 'gsun@example.org', 'country': 'zh_CN'},
#  {'email': 'gtaylor@example.com', 'country': 'en_US'},
#  {'email': 'gtorres@example.net', 'country': 'fr_FR'},
#  {'email': 'guardiaraul@example.com', 'country': 'es_ES'},
#  {'email': 'guarinobompiani@example.net', 'country': 'it_IT'},
#  {'email': 'guenter63@example.com', 'country': 'de_DE'},
#  {'email': 'guenther97@example.com', 'country': 'de_DE'},
#  {'email': 'guilbertlaetitia@example.net', 'country': 'fr_FR'},
#  {'email': 'guillonjuliette@example.net', 'country': 'fr_FR'},
#  {'email': 'guiying45@example.net', 'country': 'zh_TW'},
#  {'email': 'guiying53@example.net', 'country': 'zh_CN'},
#  {'email': 'guiying60@example.net', 'country': 'zh_TW'},
#  {'email': 'guiying83@example.net', 'country': 'zh_TW'},
#  {'email': 'guiying85@example.com', 'country': 'zh_TW'},
#  {'email': 'guiyingchang@example.com', 'country': 'zh_CN'},
#  {'email': 'guiyingdu@example.org', 'country': 'zh_TW'},
#  {'email': 'guiyinghou@example.net', 'country': 'zh_TW'},
#  {'email': 'guiyinglai@example.org', 'country': 'zh_CN'},
#  {'email': 'guiyingmao@example.com', 'country': 'zh_TW'},
#  {'email': 'guiyingmo@example.net', 'country': 'zh_CN'},
#  {'email': 'guiyingpeng@example.org', 'country': 'zh_TW'},
#  {'email': 'gumprichbernhardine@example.net', 'country': 'de_DE'},
#  {'email': 'guolei@example.net', 'country': 'zh_CN'},
#  {'email': 'guoyang@example.com', 'country': 'zh_TW'},
#  {'email': 'gurevagalina@example.org', 'country': 'ru_RU'},
#  {'email': 'gustavo87@example.net', 'country': 'it_IT'},
#  {'email': 'gusti33@example.org', 'country': 'de_DE'},
#  {'email': 'gutierrezcalixta@example.com', 'country': 'es_ES'},
#  {'email': 'gutierrezmichelle@example.com', 'country': 'en_US'},
#  {'email': 'guujin@example.org', 'country': 'ko_KR'},
#  {'email': 'guxiulan@example.org', 'country': 'zh_TW'},
#  {'email': 'guy95@example.net', 'country': 'fr_FR'},
#  {'email': 'guyan@example.com', 'country': 'zh_CN'},
#  {'email': 'guzmanstephanie@example.org', 'country': 'en_US'},
#  {'email': 'gvicente@example.com', 'country': 'es_ES'},
#  {'email': 'gwesack@example.org', 'country': 'de_DE'},
#  {'email': 'gyang@example.com', 'country': 'ko_KR'},
#  {'email': 'gyeonghyi16@example.org', 'country': 'ko_KR'},
#  {'email': 'gyeonghyi37@example.com', 'country': 'ko_KR'},
#  {'email': 'gyeongjayun@example.net', 'country': 'ko_KR'},
#  {'email': 'gyeongsug12@example.com', 'country': 'ko_KR'},
#  {'email': 'gyeongsug32@example.org', 'country': 'ko_KR'},
#  {'email': 'gyeongsug54@example.org', 'country': 'ko_KR'},
#  {'email': 'gyeongsug92@example.com', 'country': 'ko_KR'},
#  {'email': 'gyeongsugheo@example.org', 'country': 'ko_KR'},
#  {'email': 'gzhong@example.org', 'country': 'zh_TW'},
#  {'email': 'gzimina@example.com', 'country': 'ru_RU'},
#  {'email': 'h-dieter40@example.org', 'country': 'de_DE'},
#  {'email': 'h-dieterhartmann@example.net', 'country': 'de_DE'},
#  {'email': 'haeungim@example.com', 'country': 'ko_KR'},
#  {'email': 'haeungim@example.org', 'country': 'ko_KR'},
#  {'email': 'haeunna@example.org', 'country': 'ko_KR'},
#  {'email': 'halinascholl@example.org', 'country': 'de_DE'},
#  {'email': 'hanakoishikawa@example.com', 'country': 'ja_JP'},
#  {'email': 'hanhyeonsug@example.net', 'country': 'ko_KR'},
#  {'email': 'hans-adolfmans@example.com', 'country': 'de_DE'},
#  {'email': 'hans-christianatzler@example.net', 'country': 'de_DE'},
#  {'email': 'hans-heinrich04@example.com', 'country': 'de_DE'},
#  {'email': 'hans-walter14@example.org', 'country': 'de_DE'},
#  {'email': 'hans-wernerreuter@example.com', 'country': 'de_DE'},
#  ...]

# %% [markdown]
# #### GET /user/{email}: Devuelve todos los campos de un usuario. Además, incluye todos los comentarios que ha realizado. De cada comentario incluye, el texto, la fecha de creación, la categoría, el id (Room.IdR) y nombre (Room.name) de la habitación a la que hace referencia el comentario, el id(Dungeon.IdD) y nombre(Dungeon.name) de la mazmorra donde está la habitación.

# %%
def get_user_id(email):
    # Definir el filtro y la proyección
    filter = {"email": email}
    project = {
        "_id": 0,
        "email": 1,
        "username": 1,
        "country": 1,
        "hints": 1,
    }

    # Ejecutar la consulta
    result = run_query(filter, project, "Users")
    return result


get_user_id(email="aaron03@example.com")
# Out:
# [{'email': 'aaron03@example.com',
#   'hints': [{'text': 'Write already region help. Often blue board century.\\nSource important line happy him. As role firm.\\nDog natural five available high thousand. Student when phone help.\\nNice campaign produce identify. Tree particular image how fight. National now look center trip possible board.\\nFriend beautiful sign must plan evening answer. Federal result anything determine decide mind.\\nShe activity want join. There product daughter development.\\nWin send gun pull short.\\nHospital service person theory heart law c',
#     'category': 'lore',
#     'creation_date': '2019-02-05 03:15:54.000000',
#     'referemces_room': {'room_id': 296,
#      'room_name': 'storage room of kings',
#      'dungeon_id': 7,
#      'dungeon_name': 'Watergarth, Stockade of the Feminist Presidents'}},
#    {'text': 'Pick sign concern laugh give thus police. Author truth person new road number.\\nSense leader decade traditional few. Instead final thought allow ok environmental television. Behind employee pass.\\nTerm method under. Between collection task authority piece the.\\nThought scene star. Management discussion that mind. Prove draw more.\\nRange save foreign simply us. Mission action everyone laugh help miss.\\nNature I social consider animal benefit. Girl student level whatever whatever hot.\\nItself report pla',
#     'category': 'bug',
#     'creation_date': '2019-10-25 01:52:05.000000',
#     'referemces_room': {'room_id': 97,
#      'room_name': 'workshop of stoners',
#      'dungeon_id': 3,
#      'dungeon_name': 'Wanton, Culverts of the Jealous Thieves'}}],
#   'country': 'en_US'}]

# %% [markdown]
# #### POST /comment: Añade un nuevo comentario. Necesita de autenticación de usuario.
# - ##### Parametros: user_email (str), room_id (int), text (str), category (str).

# %%
def post_comment(email, room_id, text, category):
    # Dado el id de una habitación, obtener room_name, dungeon_id y dungeon_name
    filter_room = {"room_id": room_id}
    project_room = {"room_name": 1, "dungeon_id": 1, "dungeon_name": 1, "_id": 0}
    room = run_query(filter_room, project_room, "Rooms")
    room_name = room[0]["room_name"]
    dungeon_id = room[0]["dungeon_id"]
    dungeon_name = room[0]["dungeon_name"]
 
    # Dado el email de un usuario, obtener user_name, country y creation_date
    filter_email = {"email": email}
    project_email = {"user_name": 1, "country": 1, "creation_date": 1, "_id": 0}
    user = run_query(filter_email, project_email, "Users")
    user_name = user[0]["user_name"]
    country = user[0]["country"]
    creation_date = user[0]["creation_date"]

    # Crear los docuemntos a insertar
    created_at = datetime.now().strftime("%Y-%m-%d %H:%M:%S.%f")
    comment_room = {
        "category": category,
        "hintText": text,
        "published_by": {
            "email": email,
            "country": country,
            "user_name": user_name,
            "creation_date": creation_date,
        },
        "creation_date": created_at,
    }

    comment_user = {
        "text": text,
        "category": category,
        "creation_date": created_at,
        "referemces_room": {
            "room_id": room_id,
            "room_name": room_name,
            "dungeon_id": dungeon_id,
            "dungeon_name": dungeon_name,
        },
    }

    # Insertar los documentos
    run_append([comment_room], "Rooms", filter_room, "hints")
    run_append([comment_user], "Users", filter_email, "hints")


post_comment("aaoki@example.com", 5, "This is a test comment", "lore")

# %% [markdown]
# #### POST /monster: Añade un nuevo monstruo al juego. Necesita de autenticación de admin.
# - ##### Parámetros en cabecera: name (str), type (str), level (int), place (str), exp (float), manPage (int).

# %%
def post_monster(id, name, type, level, place, exp, man_page):
    data = {
        "id": id,
        "exp": exp,
        "name": name,
        "type": type,
        "level": level,
        "place": place,
        "in_rooms": None,
        "man_page": man_page,
    }
    run_insert(data, "Monster")


post_monster(266, "Goblin", "Humanoid", 1, "Dungeon", 100, 2)

# %%
def post_monster(name, type, level, place, exp, man_page):
    # Get the next id using max aggregation
    pipeline = [{"$group": {"_id": None, "max_id": {"$max": "$id"}}}]
    result = run_aggregate(pipeline, "Monster")

    monster_id = result[0]["max_id"] + 1

    data = {
        "id": monster_id,
        "exp": exp,
        "name": name,
        "type": type,
        "level": level,
        "place": place,
        "in_rooms": None,
        "man_page": man_page,
    }
    run_insert(data, "Monster")
    print(f"Añadido el monstruo {name} con id {monster_id}")


post_monster("Goblin Plus", "Humanoid", 2, "Dungeon", 110, 2)
# Out:
# Añadido el monstruo Goblin Plus con id 267

# %% [markdown]
# #### POST /loot: Añade un nuevo objeto al juego. Necesita de autenticación de admin.
# - ##### Parámetros en cabecera: name (str), type1 (str), type2 (str), weight (str), gold (float).

# %%
def post_loot(id, name, type1, type2, weight, gold):
    data = {
        "id": id,
        "gold": gold,
        "name": name,
        "type1": type1,
        "type2": type2,
        "weight": weight,
        "in_rooms": None,
    }
    run_insert(data, "Loot")


post_loot(383, "Platinum coin", "Coin", "Platinum", 0.1, 1000)

# %%
def post_loot(name, type1, type2, weight, gold):
    # Get the next id using max aggregation
    pipeline = [{"$group": {"_id": None, "max_id": {"$max": "$id"}}}]
    result = run_aggregate(pipeline, "Loot")

    loot_id = result[0]["max_id"] + 1

    data = {
        "id": loot_id,
        "gold": gold,
        "name": name,
        "type1": type1,
        "type2": type2,
        "weight": weight,
        "in_rooms": None,
    }
    run_insert(data, "Loot")
    print(f"Añadido el loot {name} con id {loot_id}")


post_loot("Platinum coin Plus", "Coin", "Platinum", 0.1, 1000)
# Out:
# Añadido el loot Platinum coin Plus con id 384

# %% [markdown]
# #### POST /room: Añade una nueva habitación a una mazmorra. Necesita de autenticación de admin.
# - ##### Parámetros de cabecera: dungeon_id (int), dungeon_name(str), dungeon_lore(str), room_name (str), rooms_connected (list[int]), [inWP(str)], [outWP(str)].

# %%
def post_room(
    room_id,
    room_name,
    dungeon_id,
    dungeon_name,
    rooms_connected,
    in_waypoint=None,
    out_waypoint=None,
):
    filter_connections = {"room_id": {"$in": rooms_connected}}

    project_connections = {"room_id": 1, "room_name": 1, "_id": 0}

    rooms = run_query(filter_connections, project_connections, "Rooms")

    data = {
        "Loot": None,
        "hints": None,
        "room_id": room_id,
        "monsters": None,
        "room_name": room_name,
        "dungeon_id": dungeon_id,
        "in_waypoint": in_waypoint,
        "dungeon_name": dungeon_name,
        "out_waypoint": out_waypoint,
        "rooms_connected": rooms,
    }
    run_insert(data, "Rooms")


post_room(
    719,
    "test_room",
    19,
    "Dalhylles, Culverts of the Grumpy Bandits",
    [718],
    in_waypoint=718,
    out_waypoint=None,
)

# %%
def post_room(
    room_name,
    dungeon_id,
    dungeon_name,
    rooms_connected,
    in_waypoint=None,
    out_waypoint=None,
):
    # Get the next id using max aggregation
    pipeline = [{"$group": {"_id": None, "max_id": {"$max": "$room_id"}}}]
    result = run_aggregate(pipeline, "Rooms")

    room_id = result[0]["max_id"] + 1

    filter_connections = {"room_id": {"$in": rooms_connected}}

    project_connections = {"room_id": 1, "room_name": 1, "_id": 0}

    rooms = run_query(filter_connections, project_connections, "Rooms")

    data = {
        "Loot": None,
        "hints": None,
        "room_id": room_id,
        "monsters": None,
        "room_name": room_name,
        "dungeon_id": dungeon_id,
        "in_waypoint": in_waypoint,
        "dungeon_name": dungeon_name,
        "out_waypoint": out_waypoint,
        "rooms_connected": rooms,
    }
    run_insert(data, "Rooms")

    run_append(
        [{"room_id": room_id, "room_name": room_name}],
        "Rooms",
        filter_connections,
        "rooms_connected",
    )

    print(f"Añadida la habitación {room_name} con id {room_id}")


post_room(
    "test_room",
    19,
    "Dalhylles, Culverts of the Grumpy Bandits",
    [719],
    in_waypoint=719,
    out_waypoint=None,
)
# Out:
# Añadida la habitación test_room con id 720

# %% [markdown]
# #### PUT /room/{room_id}/monster: Sobrescribe los monstruos de una sala de una mazmorra, los monstruo debe de existir.
# - ##### Parámetros cabecera: monsters(list[int])

# %%
def put_room_monsters(room_id, monster):
    # First, check if all the monsters exist
    filter_monster = {"id": {"$in": monster}}
    project_monster = {
        "id": 1,
        "exp": 1,
        "name": 1,
        "type": 1,
        "level": 1,
        "place": 1,
        "man_page": 1,
        "_id": 0,
    }
    result_monster = run_query(filter_monster, project_monster, "Monster")
    if len(result_monster) != len(set(monster)):
        raise ValueError("One or more monsters do not exist")

    # Duplicate the monster documents that are duplicated in monster
    # Use Counter to count occurrences in monster
    monster_counter = dict(Counter(monster))

    # Iterate over the items and counts in the monster_counter dictionary
    for item, count in monster_counter.items():
        if count > 1:
            # Get the data of the monster from the result_monster list
            monster_data = [
                monster for monster in result_monster if monster["id"] == item
            ][0]
            # Duplicate the monster_data count - 1 times
            result_monster.extend([monster_data] * (count - 1))

    # Now, get the current monster
    filter_room = {"room_id": room_id}
    project_room_monster = {"monsters.id": 1, "_id": 0}

    # Append an empty array to the monster collection, since $pull does not work with null values
    run_append([], "Rooms", filter_room, "monsters")
    monster_in_room = run_query(filter_room, project_room_monster, "Rooms")
    old_monster_ids = [monster["id"] for monster in monster_in_room[0]["monsters"]]

    project_room = {
        "room_id": 1,
        "room_name": 1,
        "dungeon_id": 1,
        "dungeon_name": 1,
        "_id": 0,
    }
    room = run_query(filter_room, project_room, "Rooms")[0]

    # Now, delete the old monster by deleting the documents in the monster array in the old monster ids with the room_id

    filter_old_monster_room = {"id": {"$in": old_monster_ids}}
    update_old_monster_room = {"$pull": {"in_rooms": {"room_id": room_id}}}
    db = get_db()

    try:
        db["Monster"].update_many(filter_old_monster_room, update_old_monster_room)
    except WriteError:
        # Add an empty array to the monster collection, since $pull does not work with null values
        run_append([], "Monster", filter_old_monster_room, "in_rooms")
        db["Monster"].update_many(filter_old_monster_room, update_old_monster_room)

    db.client.close()

    # Now, add the new monster to the monster collection
    for monster_id, amount in monster_counter.items():
        in_rooms = {"amount": amount, **room}
        filter_monster_each = {"id": monster_id}
        run_append([in_rooms], "Monster", filter_monster_each, "in_rooms")

    # Set the monster array to null
    db = get_db()
    db["Rooms"].update_one(filter_room, {"$set": {"monsters": None}})

    # Add the new monster to the room collection
    run_append(result_monster, "Rooms", filter_room, "monsters")


put_room_monsters(719, [266, 267, 267])

# %% [markdown]
# #### PUT /room/{room_id}/loot: Sobrescribe los tesoros de una sala de una mazmorra, los tesoros deben de existir.
# - ##### Parámetros cabecera: loot(list[int])

# %%
def put_room_loot(room_id, loot):
    # First, check if all the loots exist
    filter_loot = {"id": {"$in": loot}}
    project_loot = {
        "id": 1,
        "gold": 1,
        "name": 1,
        "type1": 1,
        "type2": 1,
        "weight": 1,
        "_id": 0,
    }
    result_loot = run_query(filter_loot, project_loot, "Loot")
    if len(result_loot) != len(set(loot)):
        raise ValueError("One or more loots do not exist")

    # Duplicate the loot documents that are duplicated in loot
    # Use Counter to count occurrences in loot
    loot_counter = dict(Counter(loot))

    # Iterate over the items and counts in the loot_counter dictionary
    for item, count in loot_counter.items():
        if count > 1:
            # Get the data of the loot from the result_loot list
            loot_data = [loot for loot in result_loot if loot["id"] == item][0]
            # Duplicate the loot_data count - 1 times
            result_loot.extend([loot_data] * (count - 1))

    # Now, get the current loot
    filter_room = {"room_id": room_id}
    project_room_loot = {"loot.id": 1, "_id": 0}

    # Adds empty array to loot if it is null
    run_append([], "Rooms", filter_room, "Loot")
    loot_in_room = run_query(filter_room, project_room_loot, "Rooms")
    old_loot_ids = [loot["id"] for loot in loot_in_room[0]["Loot"]]

    project_room = {
        "room_id": 1,
        "room_name": 1,
        "dungeon_id": 1,
        "dungeon_name": 1,
        "_id": 0,
    }
    room = run_query(filter_room, project_room, "Rooms")[0]

    # Now, delete the old loot by deleting the documents in the loot array in the old loot ids with the room_id

    filter_old_loot_room = {"id": {"$in": old_loot_ids}}
    update_old_loot_room = {"$pull": {"in_rooms": {"room_id": room_id}}}
    db = get_db()

    try:
        db["Loot"].update_many(filter_old_loot_room, update_old_loot_room)
    except WriteError:
        # Add an empty array to the loot collection, since $pull does not work with null values
        run_append([], "Loot", filter_old_loot_room, "in_rooms")
        db["Loot"].update_many(filter_old_loot_room, update_old_loot_room)

    db.client.close()

    # Now, add the new loot to the loot collection
    for loot_id, amount in loot_counter.items():
        in_rooms = {"amount": amount, **room}
        filter_loot_each = {"id": loot_id}
        run_append([in_rooms], "Loot", filter_loot_each, "in_rooms")

    # Set the loot array to null
    db = get_db()
    db["Rooms"].update_one(filter_room, {"$set": {"Loot": None}})

    # Add the new loot to the room collection
    run_append(result_loot, "Rooms", filter_room, "Loot")


put_room_loot(719, [383, 384, 384])

# %% [markdown]
# #### PUT /room/{room_id}/connections: Sobrescribe las conexiones de una habitación.
# - ##### Parámetros de cabecera: connections (list[int])

# %%
def put_room_connecions(room_id, rooms_connected):
    # First, check if all the rooms exist
    filter_rooms = {"room_id": {"$in": rooms_connected}}
    project = {"room_id": 1, "room_name": 1, "_id": 0}
    result_rooms = run_query(filter_rooms, project, "Rooms")
    if len(result_rooms) != len(rooms_connected):
        raise ValueError("One or more rooms do not exist")

    # Now, get the current connections
    filter_room = {"room_id": room_id}
    project = {"rooms_connected": 1, "_id": 0}

    current_connections = run_query(filter_room, project, "Rooms")[0]["rooms_connected"]

    current_ids = [room["room_id"] for room in current_connections]

    # Rooms deleted
    rooms_deleted = list(set(current_ids) - set(rooms_connected))

    # Rooms added
    rooms_added = list(set(rooms_connected) - set(current_ids))

    # From rooms_deleted, delete room_id from rooms_connected
    filter_removed = {"room_id": {"$in": rooms_deleted}}
    update = {"$pull": {"rooms_connected": {"room_id": room_id}}}

    # Get the name from the current room
    filter_current = {"room_id": room_id}
    project_current = {"room_name": 1, "_id": 0}
    current_connections = run_query(filter_current, project_current, "Rooms")

    current_name = current_connections[0]["room_name"]

    db = get_db()
    db["Rooms"].update_many(filter_removed, update)
    db.client.close()

    # From rooms_added, add room_id to rooms_connected
    filter_added = {"room_id": {"$in": rooms_added}}
    run_append(
        [{"room_id": room_id, "room_name": current_name}],
        "Rooms",
        filter_added,
        "rooms_connected",
    )

    # Set the rooms_connected array to null
    db = get_db()
    db["Rooms"].update_one(filter_room, {"$set": {"rooms_connected": None}})
    db.client.close()

    # Add the new connections
    run_append(result_rooms, "Rooms", filter_room, "rooms_connected")


put_room_connecions(719, [718, 720])

# %% [markdown]
# #### DELETE /room/{room_id}/: Borra una habitación y todos los comentarios asociados a ella.

# %%
def delete_room(room_id):
    # Definir el filtro
    filter_room = {"room_id": room_id}

    # Ejecutar la consulta
    db = get_db()
    db["Rooms"].delete_one(filter_room)

    # Buscar, en todos los usuarios, los hints que hacen referencia a la habitación eliminada y eliminarlos
    filter_users = {"hints.referemces_room.room_id": room_id}
    update_users = {"$pull": {"hints": {"referemces_room.room_id": room_id}}}

    db["Users"].update_many(filter_users, update_users)

    # Buscar en todos los monstruos, los in_rooms que hacen referencia a la habitación eliminada y eliminarlos
    filter_monsters = {"in_rooms.room_id": room_id}
    update_monsters = {"$pull": {"in_rooms": {"room_id": room_id}}}

    db["Monster"].update_many(filter_monsters, update_monsters)

    # Buscar en todos los loots, los in_rooms que hacen referencia a la habitación eliminada y eliminarlos
    filter_loots = {"in_rooms.room_id": room_id}
    update_loots = {"$pull": {"in_rooms": {"room_id": room_id}}}
    db["Loot"].update_many(filter_loots, update_loots)

    db.client.close()


delete_room(720)

# %% [markdown]
# #### DELETE /monster/{monster_id}/: Borra un monstruo.

# %%
def delete_monster(id):
    # Definir el filtro
    filter_monster = {"id": id}

    # Ejecutar la consulta
    db = get_db()
    db["Monster"].delete_one(filter_monster)

    filter_room = {"monsters.id": id}

    # En todas las rooms, eliminar el monster con id
    update = {"$pull": {"monsters": {"id": id}}}
    db["Rooms"].update_many(filter_room, update)

    db.client.close()


delete_monster(266)

# %% [markdown]
# #### DELETE /loot/{loot_id}/: Borra un tesoro.

# %%
def delete_loot(id):
    # Definir el filtro
    filter_loot = {"id": id}

    # Ejecutar la consulta
    db = get_db()
    db["Loot"].delete_one(filter_loot)

    filter_room = {"loot.id": id}

    # En todas las rooms, eliminar el loot con id
    update = {"$pull": {"Loot": {"id": id}}}
    db["Rooms"].update_many(filter_room, update)

    db.client.close()


delete_loot(383)
